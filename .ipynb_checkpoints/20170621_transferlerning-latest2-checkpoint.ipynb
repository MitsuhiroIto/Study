# %% [markdown]
# # Transfer Learningのお勉強
#
# *20170621 Mitsuhiro Ito*
#
# 自分で書いてみよう！
# 目標　高精度な犬猫を分類するモデルの構築
#
# * [keras公式ブログ](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)
# * [keras公式ドキュメント](https://keras.io/applications)
# * [@aidiaryさんの記事](http://aidiary.hatenablog.com/entry/20170110/1484057655)
#
# ---

# %% [markdown]
# # 1. 前準備

# %%
from __future__ import print_function, division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
from utils import save_model_viz, save_weights, save_hist, plot_hist
from utils import load_mnist_3D

# %% [markdown]
# # 2. 画像ファイルの入手

# %% [markdown]
# 犬猫データはKaggleからゲットしました
# 登録がめんどくさいです
# https://www.kaggle.com/c/dogs-vs-cats/data

# %% [markdown]
# 次に画像ファイルをtrain用1000枚、validation用400枚に分けます

# %%
import os

# %%
source_dir = "/Users/mitsuhiro/Work/train"　#画像ファイルへのpath

# %%
os.makedirs("%s/data" % "/Users/mitsuhiro/Work")　#train、valid用のフォルダを順次作成
data_dir = "/Users/mitsuhiro/Work/data"

# %%
os.makedirs("%s/train" % data_dir)
os.makedirs("%s/valid" % data_dir)
train_dir = "/Users/mitsuhiro/Work/data/train"
valid_dir = "/Users/mitsuhiro/Work/data/valid"

# %%
os.makedirs("%s/dogs" % train_dir)
os.makedirs("%s/cats" % train_dir)
os.makedirs("%s/dogs" % valid_dir)
os.makedirs("%s/cats" % valid_dir)

# %%
for i in range(1000):　#train用画像ファイルを移動
    os.rename("%s/dog.%d.jpg" % (source_dir, i + 1),
              "%s/dogs/dog%04d.jpg" % (train_dir, i + 1))
    os.rename("%s/cat.%d.jpg" % (source_dir, i + 1),
              "%s/cats/cat%04d.jpg" % (train_dir, i + 1))

# %%
ls "/Users/mitsuhiro/Work/data/train/cats"

# %%
for i in range(400):#valid用画像ファイルを移動
    os.rename("%s/dog.%d.jpg" % (source_dir, 1000 + i + 1),
              "%s/dogs/dog%04d.jpg" % (valid_dir, i + 1))
    os.rename("%s/cat.%d.jpg" % (source_dir, 1000 + i + 1),
              "%s/cats/cat%04d.jpg" % (valid_dir, i + 1))

# %% [markdown]
# こんな感じになりました
#
#     data/
#         train/
#               dogs/
#                   dog.0001.jpg  ...  dog.1000.jpg
#               cats/
#                   cat.0001.jpg  ...  cat.1000.jp
#
#         valid/
#               dogs/
#                   dog.0001.jpg  ...  dog.0400.jpg
#               cats/
#                 　cat.0001.jpg  ...  cat.0400.jpg
#
# ---

# %% [markdown]
# # 3. 画像データへ加工

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
generator = ImageDataGenerator(rescale=1.0 / 255)

# %% [markdown]
# ImageDataGeneratorによりリアルタイムに，画像データを生成する
# 引数にはいろいろあるがrescaleなしで4-1.のCNNをやった場合、val_actが0.5付近から全然増えない...
#
# ImageDataGenerator参考
# https://keras.io/ja/preprocessing/image/

# %%
train_generator = generator.flow_from_directory('data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary',
        shuffle=False)
valid_generator = generator.flow_from_directory('data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary',
        shuffle=False)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %% [markdown]
# このgeneratorに渡せばデータ化してくれる
#
# ---
#
#
#
#
# # 4.1 モデル構築＆評価　CNN

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
train_generator = generator.flow_from_directory('data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')
valid_generator = generator.flow_from_directory('data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
RUN_ID = 'CNN'
save_model_viz(RUN_ID, model)

# %%
batch_size = 16
hist = model.fit_generator(train_generator, 
                    steps_per_epoch = 2000 // batch_size, 
                    epochs=20, 
                    verbose=1, 
                    validation_data = valid_generator,
                    validation_steps= 800 // batch_size)

save_weights(RUN_ID, model)
save_hist(RUN_ID, hist)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 6s - loss: 0.6948 - acc: 0.5325 - val_loss: 0.6853 - val_acc: 0.6200
# Epoch 2/20
# 125/125 [==============================] - 6s - loss: 0.6829 - acc: 0.5725 - val_loss: 0.6935 - val_acc: 0.4988
# Epoch 3/20
# 125/125 [==============================] - 6s - loss: 0.6748 - acc: 0.5790 - val_loss: 0.6567 - val_acc: 0.5813
# Epoch 4/20
#  - ETA: 1s - loss: 0.6295 - acc: 0.6490
# Epoch 5/20
# 125/125 [==============================] - 6s - loss: 0.5973 - acc: 0.6830 - val_loss: 0.6301 - val_acc: 0.6512
# Epoch 6/20
# 125/125 [==============================] - 6s - loss: 0.5488 - acc: 0.7150 - val_loss: 0.6102 - val_acc: 0.6800
# Epoch 7/20
# 125/125 [==============================] - 6s - loss: 0.4940 - acc: 0.7565 - val_loss: 0.6071 - val_acc: 0.6800
# Epoch 8/20
# 125/125 [==============================] - 6s - loss: 0.4206 - acc: 0.8030 - val_loss: 0.6315 - val_acc: 0.6900
# Epoch 9/20
# 125/125 [==============================] - 6s - loss: 0.3768 - acc: 0.8275 - val_loss: 0.6772 - val_acc: 0.6925
# Epoch 10/20
# 125/125 [==============================] - 6s - loss: 0.3085 - acc: 0.8630 - val_loss: 0.6776 - val_acc: 0.6825
# Epoch 11/20
# 125/125 [==============================] - 6s - loss: 0.2532 - acc: 0.8840 - val_loss: 0.7341 - val_acc: 0.6950
# Epoch 12/20
# 125/125 [==============================] - 6s - loss: 0.1823 - acc: 0.9250 - val_loss: 0.9531 - val_acc: 0.7000
# Epoch 13/20
#  - ETA: 2s - loss: 0.1833 - acc: 0.9404
# Epoch 14/20
# 125/125 [==============================] - 6s - loss: 0.1459 - acc: 0.9425 - val_loss: 0.8524 - val_acc: 0.6787
# Epoch 15/20
# 125/125 [==============================] - 6s - loss: 0.1304 - acc: 0.9510 - val_loss: 0.9710 - val_acc: 0.7212
# Epoch 16/20
#  - ETA: 2s - loss: 0.0973 - acc: 0.9622
# Epoch 17/20
# 125/125 [==============================] - 6s - loss: 0.0929 - acc: 0.9645 - val_loss: 1.0893 - val_acc: 0.7275
# Epoch 18/20
# 125/125 [==============================] - 6s - loss: 0.0917 - acc: 0.9645 - val_loss: 1.1607 - val_acc: 0.6887
# Epoch 19/20
# 125/125 [==============================] - 6s - loss: 0.0786 - acc: 0.9705 - val_loss: 1.4838 - val_acc: 0.7063
# Epoch 20/20
# 125/125 [==============================] - 6s - loss: 0.0755 - acc: 0.9685 - val_loss: 1.3288 - val_acc: 0.7050

# %%
plot_hist(RUN_ID)

# %%
from IPython.display import Image
Image("model/CNN_vis.png", width=200)

# %%
from IPython.display import Image
Image("model/CNN_vis.png", width=200)

# %% [markdown]
# ---
#
# # 4.2 モデル構築＆評価　VGG16を特長抽出機として使用
#
# ---
#
# まずはVGG16を使って特徴量を抽出して保存

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
train_generator = generator.flow_from_directory('data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode=None,
        shuffle=False)
valid_generator = generator.flow_from_directory('data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode=None,
        shuffle=False)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
from keras.applications.vgg16 import VGG16

# %%
model = VGG16(include_top=False, weights='imagenet') # include_top=Fals :VGG16のFC部分を削除

# %%
batch_size = 16
bottleneck_features_train = model.predict_generator(train_generator, 2000 // batch_size, verbose = 1)
# Out:
# 125/125 [==============================] - 5s

# %%
print(bottleneck_features_train.shape)
# Out:
# (2000, 4, 4, 512)

# %%
np.save(open('bottleneck_features_train.npy', 'wb'), bottleneck_features_train)

# %%
batch_size = 16
bottleneck_features_valid = model.predict_generator(valid_generator, 800 // batch_size , verbose = 1)
# Out:
# 50/50 [==============================] - 1s

# %%
np.save(open('bottleneck_features_valid.npy', 'wb'), bottleneck_features_valid)

# %% [markdown]
# ---
#
# 次に抽出した特徴量をinputとするFC層を作る

# %%
train_data = np.load(open('bottleneck_features_train.npy', 'rb'))
train_labels = np.array([0] * 1000 + [1] * 1000)

# %%
valid_data = np.load(open('bottleneck_features_valid.npy','rb'))
valid_labels = np.array([0] * 400 + [1] * 400)

# %%
print(train_data.shape)
print(valid_data.shape)
# Out:
# (2000, 4, 4, 512)
# (800, 4, 4, 512)

# %%
model = Sequential()
model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
RUN_ID = 'Feature_FC'
save_model_viz(RUN_ID, model)

# %%
hist = model.fit(train_data, train_labels,
          epochs=20,
          batch_size=batch_size,
          validation_data=(valid_data, valid_labels))

save_weights(RUN_ID, model)
save_hist(RUN_ID, hist)
# Out:
# Train on 2000 samples, validate on 800 samples
# Epoch 1/20
# 2000/2000 [==============================] - 0s - loss: 0.6848 - acc: 0.7625 - val_loss: 0.4021 - val_acc: 0.8150
# Epoch 2/20
# 2000/2000 [==============================] - 0s - loss: 0.3571 - acc: 0.8570 - val_loss: 0.3035 - val_acc: 0.8725
# Epoch 3/20
# 2000/2000 [==============================] - 0s - loss: 0.3108 - acc: 0.8835 - val_loss: 0.2781 - val_acc: 0.8912
# Epoch 4/20
# 2000/2000 [==============================] - 0s - loss: 0.2492 - acc: 0.8970 - val_loss: 0.2679 - val_acc: 0.8850
# Epoch 5/20
# 2000/2000 [==============================] - 0s - loss: 0.2167 - acc: 0.9125 - val_loss: 0.2474 - val_acc: 0.9087
# Epoch 6/20
# 2000/2000 [==============================] - 0s - loss: 0.1806 - acc: 0.9405 - val_loss: 0.2559 - val_acc: 0.9125
# Epoch 7/20
# 2000/2000 [==============================] - 0s - loss: 0.1623 - acc: 0.9340 - val_loss: 0.4460 - val_acc: 0.8662
# Epoch 8/20
# 2000/2000 [==============================] - 0s - loss: 0.1565 - acc: 0.9380 - val_loss: 0.3548 - val_acc: 0.8812
# Epoch 9/20
# 2000/2000 [==============================] - 0s - loss: 0.1400 - acc: 0.9455 - val_loss: 0.3752 - val_acc: 0.8950
# Epoch 10/20
# 2000/2000 [==============================] - 0s - loss: 0.1160 - acc: 0.9580 - val_loss: 0.4272 - val_acc: 0.8775
# Epoch 11/20
# 2000/2000 [==============================] - 0s - loss: 0.1023 - acc: 0.9555 - val_loss: 0.4100 - val_acc: 0.8988
# Epoch 12/20
# 2000/2000 [==============================] - 0s - loss: 0.1078 - acc: 0.9605 - val_loss: 0.7429 - val_acc: 0.8438
# Epoch 13/20
# 2000/2000 [==============================] - 0s - loss: 0.0884 - acc: 0.9685 - val_loss: 0.4132 - val_acc: 0.9012
# Epoch 14/20
# 2000/2000 [==============================] - 0s - loss: 0.0772 - acc: 0.9695 - val_loss: 0.6998 - val_acc: 0.8550
# Epoch 15/20
# 2000/2000 [==============================] - 0s - loss: 0.0967 - acc: 0.9730 - val_loss: 0.5508 - val_acc: 0.8975
# Epoch 16/20
# 2000/2000 [==============================] - 0s - loss: 0.0602 - acc: 0.9750 - val_loss: 0.4754 - val_acc: 0.8962
# Epoch 17/20
# 2000/2000 [==============================] - 0s - loss: 0.0726 - acc: 0.9730 - val_loss: 0.4961 - val_acc: 0.9000
# Epoch 18/20
# 2000/2000 [==============================] - 0s - loss: 0.0486 - acc: 0.9795 - val_loss: 0.5482 - val_acc: 0.9000
# Epoch 19/20
# 2000/2000 [==============================] - 0s - loss: 0.0516 - acc: 0.9845 - val_loss: 0.5378 - val_acc: 0.9012
# Epoch 20/20
# 2000/2000 [==============================] - 0s - loss: 0.0477 - acc: 0.9840 - val_loss: 0.6163 - val_acc: 0.8962

# %%
plot_hist(RUN_ID)

# %%
from IPython.display import Image
Image("model/Feature-FC_vis.png", width=200)

# %% [markdown]
# # 4.3 モデル構築＆評価　VGG16によるFine tuning

# %%
from keras import applications
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Input, Dense
from keras.layers import Activation, Dropout, Flatten
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
generator = ImageDataGenerator(rescale=1.0 / 255)

# %%
train_generator = generator.flow_from_directory('data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary',
        shuffle=False)
valid_generator = generator.flow_from_directory('data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary',
        shuffle=False)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
input_tensor = Input(shape=(150,150,3))
vgg_model = applications.VGG16(weights='imagenet', input_tensor=input_tensor, include_top=False)

# %%
top_model = Sequential()
top_model.add(Flatten(input_shape=vgg_model.output_shape[1:]))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# %%
model = Model(input=vgg_model.input, output=top_model(vgg_model.output))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("se..., inputs=Tensor("in...)`
#   if __name__ == '__main__':

# %% [markdown]
# model.add(top_model)は使えない

# %%
for layer in model.layers[:15]:
        layer.trainable = False

# %%
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])

# %%
RUN_ID = 'Fine tuning'
save_model_viz(RUN_ID, model)

# %%
batch_size=16
hist = model.fit_generator(train_generator, 
                    steps_per_epoch = 2000 // batch_size, 
                    epochs=100, 
                    verbose=1, 
                    validation_data = valid_generator,
                    validation_steps= 800 // batch_size)

save_weights(RUN_ID, model)
save_hist(RUN_ID, hist)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 7s - loss: 0.4138 - acc: 0.8885 - val_loss: 2.1816 - val_acc: 0.5000
# Epoch 2/100
# 125/125 [==============================] - 7s - loss: 1.0033 - acc: 0.4280 - val_loss: 0.6878 - val_acc: 0.5000
# Epoch 3/100
# 125/125 [==============================] - 7s - loss: 0.6970 - acc: 0.4530 - val_loss: 0.6791 - val_acc: 0.5000
# Epoch 4/100
# 125/125 [==============================] - 7s - loss: 0.6833 - acc: 0.4860 - val_loss: 0.6688 - val_acc: 0.5000
# Epoch 5/100
# 125/125 [==============================] - 7s - loss: 0.0097 - acc: 0.9990 - val_loss: 0.2815 - val_acc: 0.9250
# Epoch 77/100
# 125/125 [==============================] - 7s - loss: 0.0094 - acc: 1.0000 - val_loss: 0.2740 - val_acc: 0.9313
# Epoch 78/100
# 125/125 [==============================] - 7s - loss: 0.0081 - acc: 1.0000 - val_loss: 0.2754 - val_acc: 0.9300
# Epoch 79/100
# 125/125 [==============================] - 7s - loss: 0.0079 - acc: 0.9990 - val_loss: 0.2901 - val_acc: 0.9263
# Epoch 80/100
# 125/125 [==============================] - 7s - loss: 0.0079 - acc: 0.9995 - val_loss: 0.2803 - val_acc: 0.9263
# Epoch 81/100
# 125/125 [==============================] - 7s - loss: 0.0079 - acc: 0.9995 - val_loss: 0.2773 - val_acc: 0.9263
# Epoch 82/100
# 125/125 [==============================] - 7s - loss: 0.0073 - acc: 0.9995 - val_loss: 0.2885 - val_acc: 0.9275
# Epoch 83/100
# 125/125 [==============================] - 7s - loss: 0.0077 - acc: 0.9995 - val_loss: 0.2773 - val_acc: 0.9325
# Epoch 84/100
# 125/125 [==============================] - 7s - loss: 0.0053 - acc: 1.0000 - val_loss: 0.2817 - val_acc: 0.9325
# Epoch 85/100
# 125/125 [==============================] - 7s - loss: 0.0054 - acc: 1.0000 - val_loss: 0.2817 - val_acc: 0.9337
# Epoch 86/100
# 125/125 [==============================] - 7s - loss: 0.0043 - acc: 1.0000 - val_loss: 0.2856 - val_acc: 0.9337
# Epoch 87/100
# 125/125 [==============================] - 7s - loss: 0.0057 - acc: 0.9995 - val_loss: 0.2909 - val_acc: 0.9287
# Epoch 88/100
# 125/125 [==============================] - 7s - loss: 0.0059 - acc: 1.0000 - val_loss: 0.2846 - val_acc: 0.9325
# Epoch 89/100
# 125/125 [==============================] - 7s - loss: 0.0049 - acc: 1.0000 - val_loss: 0.2834 - val_acc: 0.9337
# Epoch 90/100
# 125/125 [==============================] - 7s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.2883 - val_acc: 0.9325
# Epoch 91/100
# 125/125 [==============================] - 7s - loss: 0.0045 - acc: 1.0000 - val_loss: 0.2909 - val_acc: 0.9325
# Epoch 92/100
# 125/125 [==============================] - 7s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.2868 - val_acc: 0.9337
# Epoch 93/100
# 125/125 [==============================] - 7s - loss: 0.0038 - acc: 1.0000 - val_loss: 0.2892 - val_acc: 0.9337
# Epoch 94/100
# 125/125 [==============================] - 7s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.2923 - val_acc: 0.9337
# Epoch 95/100
# 125/125 [==============================] - 7s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.2951 - val_acc: 0.9337
# Epoch 96/100
# 125/125 [==============================] - 7s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.2955 - val_acc: 0.9337
# Epoch 97/100
# 125/125 [==============================] - 7s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.2968 - val_acc: 0.9350
# Epoch 98/100
# 125/125 [==============================] - 7s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.3009 - val_acc: 0.9337
# Epoch 99/100
# 125/125 [==============================] - 7s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.3008 - val_acc: 0.9325
# Epoch 100/100
# 125/125 [==============================] - 7s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.3025 - val_acc: 0.9337

# %%
fit_generator(self, generator, steps_per_epoch, epochs=1, verbose=1, callbacks=None, validation_data=None, 
              validation_steps=None, class_weight=None, max_q_size=10, workers=1, pickle_safe=False, initial_epoch=0)

# %%
plot_hist(RUN_ID)

# %% [markdown]
# ---
# memo

# %%
os.chdir("/Users/mitsuhiro/Desktop")

# %%
ls

# %%
os.re4name("%s/cat.14.jpg" % "/Users/mitsuhiro/Desktop" , "%s/cat.14.jpg" % "/Users/mitsuhiro/work") #%の後部分が%sに入る

# %%
# %load utils.py

# %%
# !pwd #

# %%
model.summary()
