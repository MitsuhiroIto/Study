# %% [markdown]
# # VGGNetのお勉強
#
#
# *20170620 Mitsuhiro Ito*
#
# 流れは20170619_inceptionと同じ
# ---

# %%
from __future__ import print_function, division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import urllib.request
urllib.request.urlretrieve(' https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Male_silverback_Gorilla.JPG/236px-Male_silverback_Gorilla.JPG','gorilla.jpg')
# Out:
# ('gorilla.jpg', <http.client.HTTPMessage at 0x2262b155898>)

# %%
from IPython.display import Image
Image("gorilla.jpg")

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = VGG16(weights='imagenet')

# %%
img_path = 'gorilla.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

_pred = model.predict(x)

pred = decode_predictions(_pred, top=3)[0]
print('Predicted:')
print(pred[0])
print(pred[1])
print(pred[2])
# Out:
# Predicted:
# ('n02480855', 'gorilla', 0.99992514)
# ('n02481823', 'chimpanzee', 5.4582026e-05)
# ('n02480495', 'orangutan', 7.1418322e-06)
