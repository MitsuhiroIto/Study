# %% [markdown]
# # Hyperasの練習
#
# *20170715 Mitsuhiro Ito*
#
#
# * (https://github.com/maxpumperla/hyperas/tree/master/examples)
#
#
# ---

# %%
from __future__ import print_function
import sys
from utils import save_model_viz, save_weights, save_hist, plot_hist
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import uniform, choice, conditional
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
def data():
    train_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
    
    valid_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')

    valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')
    
    
    
    return train_generator, valid_generator

# %%
def model(train_generator, valid_generator):

    model = Sequential()
    model.add(Conv2D(64, (3, 3), input_shape=(150, 150, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5)
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    
    adam = optimizers.Adam(lr={{choice([0.001, 0.0005, 0.0001])}}, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
 
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    batch_size = 16
    
              

 
    model.fit_generator(train_generator, 
                    steps_per_epoch = 2000 // batch_size, 
                    epochs=20, 
                    verbose=1, 
                    validation_data = valid_generator,
                    validation_steps= 800 // batch_size)
    
    
    score, acc = model.evaluate_generator(generator=valid_generator, 
                                      steps= 800 // batch_size)
    
    print(score, acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
train_generator, valid_generator = data()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=10,
                                      trials=Trials(),
                                      notebook_name='20170714_hyperas6' )
print("Evalutation of best performing model:")
print(best_model.evaluate_generator(valid_generator, steps=64))
print(best_run)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     from utils import save_model_viz, save_weights, save_hist, plot_hist
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from keras import optimizers
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import uniform, choice, conditional
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation, Flatten
# except:
#     pass
#
# try:
#     from keras.layers.convolutional import Convolution2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD
# except:
#     pass
#
# try:
#     from keras.preprocessing.image import ImageDataGenerator
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Conv2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.layers import Activation, Dropout, Flatten, Dense
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'lr': hp.choice('lr', [0.001, 0.0005, 0.0001]),
#     }
#
# >>> Data
#    1:
#    2: train_gan = ImageDataGenerator(rescale=1.0 / 255,
#    3:     featurewise_center=False,  # set input mean to 0 over the dataset
#    4:     samplewise_center=False,  # set each sample mean to 0
#    5:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#    6:     samplewise_std_normalization=False,  # divide each input by its std
#    7:     zca_whitening=False,  # apply ZCA whitening
#    8:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#    9:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   10:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   11:     horizontal_flip=False,  # randomly flip images
#   12:     vertical_flip=False)  # randomly flip images
#   13:
#   14: valid_gan = ImageDataGenerator(rescale=1.0 / 255,
#   15:     featurewise_center=False,  # set input mean to 0 over the dataset
#   16:     samplewise_center=False,  # set each sample mean to 0
#   17:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#   18:     samplewise_std_normalization=False,  # divide each input by its std
#   19:     zca_whitening=False,  # apply ZCA whitening
#   20:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#   21:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   22:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   23:     horizontal_flip=False,  # randomly flip images
#   24:     vertical_flip=False)  # randomly flip images
#   25:
#   26: train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
#   27:     target_size=(150, 150),
#   28:     batch_size=16,
#   29:     class_mode='binary')
#   30:
#   31: valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
#   32:     target_size=(150, 150),
#   33:     batch_size=16,
#   34:     class_mode='binary')
#   35:
#   36:
#   37:
#   38:
#   39:
#   40:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = Sequential()
#    5:     model.add(Conv2D(64, (3, 3), input_shape=(150, 150, 3)))
#    6:     model.add(Activation('relu'))
#    7:     model.add(MaxPooling2D(pool_size=(2, 2)))
#    8:
#    9:     model.add(Conv2D(64, (3, 3)))
#   10:     model.add(Activation('relu'))
#   11:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   12:
#   13:     model.add(Conv2D(64, (3, 3)))
#   14:     model.add(Activation('relu'))
#   15:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   16:
#   17:
#   18:     model.add(Flatten())
#   19:     model.add(Dense(64))
#   20:     model.add(Activation('relu'))
#   21:     model.add(Dropout(space['Dropout']))
#   22:     model.add(Dense(1))
#   23:     model.add(Activation('sigmoid'))
#   24:
#   25:     adam = optimizers.Adam(lr=space['lr'], beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#   26:
#   27:     model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
#   28:
#   29:     batch_size = 16
#   30:
#   31:
#   32:
#   33:
#   34:     model.fit_generator(train_generator,
#   35:                     steps_per_epoch = 2000 // batch_size,
#   36:                     epochs=25,
#   37:                     verbose=1,
#   38:                     validation_data = valid_generator,
#   39:                     validation_steps= 800 // batch_size)
#   40:
#   41:
#   42:     score, acc = model.evaluate_generator(generator=valid_generator,
#   43:                                       steps= 800 // batch_size)
#   44:
#   45:     print(score, acc)
#   46:
#   47:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   48:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/25
# 125/125 [==============================] - 11s - loss: 0.6966 - acc: 0.5075 - val_loss: 0.7181 - val_acc: 0.5000
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6928 - acc: 0.5425 - val_loss: 0.6881 - val_acc: 0.5875
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6754 - acc: 0.5950 - val_loss: 0.6922 - val_acc: 0.5075
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6534 - acc: 0.6075 - val_loss: 0.6703 - val_acc: 0.5737
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.5999 - acc: 0.6820 - val_loss: 0.6197 - val_acc: 0.6575
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.5350 - acc: 0.7385 - val_loss: 0.5808 - val_acc: 0.6987
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.4355 - acc: 0.8035 - val_loss: 0.6858 - val_acc: 0.6687
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.3300 - acc: 0.8510 - val_loss: 0.6781 - val_acc: 0.6887
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.2299 - acc: 0.9040 - val_loss: 0.8774 - val_acc: 0.6737
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.1415 - acc: 0.9390 - val_loss: 0.8204 - val_acc: 0.7188
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.0964 - acc: 0.9615 - val_loss: 1.1684 - val_acc: 0.7000
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.0780 - acc: 0.9705 - val_loss: 1.1693 - val_acc: 0.6900
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.0562 - acc: 0.9795 - val_loss: 1.5434 - val_acc: 0.6713
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.0618 - acc: 0.9750 - val_loss: 1.4071 - val_acc: 0.6675
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.0263 - acc: 0.9910 - val_loss: 1.5762 - val_acc: 0.6975
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0367 - acc: 0.9860 - val_loss: 1.8287 - val_acc: 0.6775
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.0384 - acc: 0.9870 - val_loss: 1.7804 - val_acc: 0.7100
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0388 - acc: 0.9875 - val_loss: 1.7013 - val_acc: 0.6925
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0174 - acc: 0.9935 - val_loss: 1.7321 - val_acc: 0.7175
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0134 - acc: 0.9935 - val_loss: 1.7484 - val_acc: 0.6825
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0213 - acc: 0.9920 - val_loss: 1.5891 - val_acc: 0.7063
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0294 - acc: 0.9880 - val_loss: 2.0195 - val_acc: 0.6538
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0330 - acc: 0.9865 - val_loss: 1.7639 - val_acc: 0.7013
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0347 - acc: 0.9865 - val_loss: 1.8428 - val_acc: 0.6887
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0155 - acc: 0.9945 - val_loss: 1.8646 - val_acc: 0.6925
# 1.95894251227 0.69875
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.7037 - acc: 0.5140 - val_loss: 0.6844 - val_acc: 0.6275
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6750 - acc: 0.5655 - val_loss: 0.6590 - val_acc: 0.5537
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6315 - acc: 0.6480 - val_loss: 0.6226 - val_acc: 0.6538
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6227 - acc: 0.6650 - val_loss: 0.6243 - val_acc: 0.6538
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.5467 - acc: 0.7200 - val_loss: 0.6241 - val_acc: 0.6512
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.5061 - acc: 0.7410 - val_loss: 0.7238 - val_acc: 0.7037
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.4819 - acc: 0.7620 - val_loss: 0.6471 - val_acc: 0.6900
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.3976 - acc: 0.8170 - val_loss: 0.6407 - val_acc: 0.7100
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.3470 - acc: 0.8405 - val_loss: 0.7665 - val_acc: 0.71370
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.3219 - acc: 0.8410 - val_loss: 0.6930 - val_acc: 0.7075
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.2425 - acc: 0.8890 - val_loss: 0.9210 - val_acc: 0.6987
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.2028 - acc: 0.9125 - val_loss: 0.9442 - val_acc: 0.7075
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.1769 - acc: 0.9205 - val_loss: 0.9183 - val_acc: 0.7200
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.1571 - acc: 0.9355 - val_loss: 1.1033 - val_acc: 0.6913
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.1236 - acc: 0.9480 - val_loss: 1.0585 - val_acc: 0.6925
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.1132 - acc: 0.9495 - val_loss: 1.2629 - val_acc: 0.7175
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.1265 - acc: 0.9475 - val_loss: 1.2305 - val_acc: 0.6800
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0975 - acc: 0.9575 - val_loss: 1.3034 - val_acc: 0.71250 - - ETA: 1s - loss: 0.09
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0993 - acc: 0.9595 - val_loss: 1.7133 - val_acc: 0.7075
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0771 - acc: 0.9670 - val_loss: 1.3846 - val_acc: 0.7312
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0671 - acc: 0.9760 - val_loss: 1.3612 - val_acc: 0.7163
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0642 - acc: 0.9730 - val_loss: 1.4145 - val_acc: 0.7450
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0587 - acc: 0.9815 - val_loss: 1.6699 - val_acc: 0.7300
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0585 - acc: 0.9765 - val_loss: 1.5681 - val_acc: 0.7338
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0581 - acc: 0.9785 - val_loss: 1.5881 - val_acc: 0.7388
# 1.57651213527 0.74125
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6988 - acc: 0.5075 - val_loss: 0.6931 - val_acc: 0.5012
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6968 - acc: 0.5025 - val_loss: 0.6930 - val_acc: 0.5062
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4965 - val_loss: 0.6932 - val_acc: 0.4925
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6942 - acc: 0.4850 - val_loss: 0.6930 - val_acc: 0.4913
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6941 - acc: 0.5165 - val_loss: 0.6896 - val_acc: 0.5525
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6903 - acc: 0.5265 - val_loss: 0.6916 - val_acc: 0.5238
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.6815 - acc: 0.5820 - val_loss: 0.6858 - val_acc: 0.5950
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.6749 - acc: 0.5760 - val_loss: 0.6841 - val_acc: 0.5800
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.6594 - acc: 0.5960 - val_loss: 0.6618 - val_acc: 0.6212
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.6527 - acc: 0.6305 - val_loss: 0.6644 - val_acc: 0.6238
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.6220 - acc: 0.6445 - val_loss: 0.6494 - val_acc: 0.6400
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.6125 - acc: 0.6680 - val_loss: 0.6359 - val_acc: 0.65750.6
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.5892 - acc: 0.6800 - val_loss: 0.6325 - val_acc: 0.6613
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.5566 - acc: 0.7035 - val_loss: 0.6246 - val_acc: 0.6925
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.5313 - acc: 0.7325 - val_loss: 0.6149 - val_acc: 0.6600
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.4867 - acc: 0.7640 - val_loss: 0.6325 - val_acc: 0.6613
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.4690 - acc: 0.7660 - val_loss: 0.6096 - val_acc: 0.6950
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.4443 - acc: 0.7865 - val_loss: 0.5995 - val_acc: 0.7275
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.4021 - acc: 0.8055 - val_loss: 0.6903 - val_acc: 0.6963
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.3944 - acc: 0.8100 - val_loss: 0.6135 - val_acc: 0.7150
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.3459 - acc: 0.8395 - val_loss: 0.7778 - val_acc: 0.6950
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.3133 - acc: 0.8480 - val_loss: 0.7321 - val_acc: 0.6963
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.3108 - acc: 0.8470 - val_loss: 0.7405 - val_acc: 0.7312
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.2690 - acc: 0.8670 - val_loss: 0.7315 - val_acc: 0.7200
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.2608 - acc: 0.8735 - val_loss: 0.7940 - val_acc: 0.7050
# 0.808921909332 0.68875
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.6996 - acc: 0.5230 - val_loss: 0.6920 - val_acc: 0.5400
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6916 - acc: 0.5460 - val_loss: 0.6950 - val_acc: 0.4738
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6687 - acc: 0.5955 - val_loss: 0.6590 - val_acc: 0.6000
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6395 - acc: 0.6500 - val_loss: 0.6102 - val_acc: 0.6687
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.5907 - acc: 0.6940 - val_loss: 0.5876 - val_acc: 0.7075
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.5350 - acc: 0.7345 - val_loss: 0.6027 - val_acc: 0.6800
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.4820 - acc: 0.7615 - val_loss: 0.6218 - val_acc: 0.7212
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.4199 - acc: 0.8005 - val_loss: 0.6015 - val_acc: 0.6887
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.3707 - acc: 0.8300 - val_loss: 0.6369 - val_acc: 0.74380.820 - ETA: 1s - lo
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.3111 - acc: 0.8590 - val_loss: 0.6690 - val_acc: 0.7188
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.2523 - acc: 0.8905 - val_loss: 0.7956 - val_acc: 0.7288
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.2107 - acc: 0.9115 - val_loss: 0.9331 - val_acc: 0.7250
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.1564 - acc: 0.9335 - val_loss: 1.0122 - val_acc: 0.7425
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.1409 - acc: 0.9365 - val_loss: 1.0795 - val_acc: 0.7050
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.1267 - acc: 0.9425 - val_loss: 1.0273 - val_acc: 0.7275
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0999 - acc: 0.9615 - val_loss: 1.4410 - val_acc: 0.7000
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.1158 - acc: 0.9505 - val_loss: 1.1270 - val_acc: 0.7063
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0831 - acc: 0.9635 - val_loss: 1.3486 - val_acc: 0.6950
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0781 - acc: 0.9675 - val_loss: 1.2680 - val_acc: 0.7300
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0682 - acc: 0.9705 - val_loss: 1.4133 - val_acc: 0.7125
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0657 - acc: 0.9755 - val_loss: 1.5014 - val_acc: 0.7150
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0550 - acc: 0.9730 - val_loss: 1.4631 - val_acc: 0.7100
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0655 - acc: 0.9730 - val_loss: 1.5272 - val_acc: 0.7275
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0657 - acc: 0.9785 - val_loss: 1.6616 - val_acc: 0.6950 0.07
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0500 - acc: 0.9790 - val_loss: 1.5276 - val_acc: 0.7188
# 1.57822405398 0.72125
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6981 - acc: 0.4900 - val_loss: 0.6927 - val_acc: 0.5850
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6931 - acc: 0.5260 - val_loss: 0.6903 - val_acc: 0.5413
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6898 - acc: 0.5305 - val_loss: 0.6836 - val_acc: 0.5962
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6770 - acc: 0.5780 - val_loss: 0.6656 - val_acc: 0.5975
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6659 - acc: 0.5740 - val_loss: 0.6622 - val_acc: 0.5988
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6384 - acc: 0.6445 - val_loss: 0.6306 - val_acc: 0.6350
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.6213 - acc: 0.6625 - val_loss: 0.5954 - val_acc: 0.6787
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.5705 - acc: 0.7060 - val_loss: 0.5685 - val_acc: 0.7063
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.5496 - acc: 0.7160 - val_loss: 0.6499 - val_acc: 0.6400
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.5160 - acc: 0.7420 - val_loss: 0.6023 - val_acc: 0.6763
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.4731 - acc: 0.7735 - val_loss: 0.6310 - val_acc: 0.6613
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.4380 - acc: 0.8005 - val_loss: 0.6657 - val_acc: 0.7000
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.4000 - acc: 0.8150 - val_loss: 0.6276 - val_acc: 0.6850
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.3583 - acc: 0.8275 - val_loss: 0.6955 - val_acc: 0.7013
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.3083 - acc: 0.8630 - val_loss: 0.6960 - val_acc: 0.6925
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.2684 - acc: 0.8835 - val_loss: 0.7932 - val_acc: 0.6863
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.2138 - acc: 0.9195 - val_loss: 0.7758 - val_acc: 0.7312
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.2011 - acc: 0.9095 - val_loss: 0.7759 - val_acc: 0.6887
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.2061 - acc: 0.9190 - val_loss: 0.9811 - val_acc: 0.6975
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.1439 - acc: 0.9390 - val_loss: 1.1600 - val_acc: 0.6875
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.1382 - acc: 0.9470 - val_loss: 0.8466 - val_acc: 0.7312
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.1123 - acc: 0.9520 - val_loss: 1.2216 - val_acc: 0.7000
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.1108 - acc: 0.9535 - val_loss: 1.0944 - val_acc: 0.7262
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0803 - acc: 0.9690 - val_loss: 1.3832 - val_acc: 0.6937
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.1086 - acc: 0.9570 - val_loss: 1.0968 - val_acc: 0.7113
# 0.978844411969 0.73625
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.6976 - acc: 0.5060 - val_loss: 0.6892 - val_acc: 0.5475
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6907 - acc: 0.5700 - val_loss: 0.6712 - val_acc: 0.6088
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6481 - acc: 0.6270 - val_loss: 0.6480 - val_acc: 0.6488
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6055 - acc: 0.6790 - val_loss: 0.5941 - val_acc: 0.6837
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.5459 - acc: 0.7200 - val_loss: 0.5935 - val_acc: 0.7075
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.4623 - acc: 0.7725 - val_loss: 0.5777 - val_acc: 0.7275
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.4055 - acc: 0.8220 - val_loss: 0.6325 - val_acc: 0.6975
# Epoch 8/25
# 125/125 [==============================] - 5s - loss: 0.3045 - acc: 0.8760 - val_loss: 0.7950 - val_acc: 0.7075
# Epoch 9/25
# 125/125 [==============================] - 7s - loss: 0.2351 - acc: 0.9010 - val_loss: 0.8770 - val_acc: 0.7150
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.1523 - acc: 0.9435 - val_loss: 1.0520 - val_acc: 0.6963
# Epoch 11/25
# 125/125 [==============================] - 5s - loss: 0.0968 - acc: 0.9650 - val_loss: 1.3415 - val_acc: 0.6863
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.0585 - acc: 0.9815 - val_loss: 1.1922 - val_acc: 0.7412
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.0390 - acc: 0.9870 - val_loss: 1.5985 - val_acc: 0.6925
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.0404 - acc: 0.9880 - val_loss: 1.3677 - val_acc: 0.7050
# Epoch 15/25
# 125/125 [==============================] - 5s - loss: 0.0486 - acc: 0.9820 - val_loss: 1.5272 - val_acc: 0.6937
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0459 - acc: 0.9830 - val_loss: 1.5054 - val_acc: 0.7125
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.0422 - acc: 0.9890 - val_loss: 1.3518 - val_acc: 0.7288
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0253 - acc: 0.9945 - val_loss: 1.4964 - val_acc: 0.6863
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0154 - acc: 0.9950 - val_loss: 1.6429 - val_acc: 0.7125
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0114 - acc: 0.9935 - val_loss: 1.7531 - val_acc: 0.7188
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0122 - acc: 0.9965 - val_loss: 1.8405 - val_acc: 0.7125
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0133 - acc: 0.9955 - val_loss: 1.6738 - val_acc: 0.7137
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0142 - acc: 0.9950 - val_loss: 1.7212 - val_acc: 0.7238
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0351 - acc: 0.9840 - val_loss: 1.8145 - val_acc: 0.6975
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0533 - acc: 0.9800 - val_loss: 1.7444 - val_acc: 0.6875
# 1.81961138278 0.68375
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6971 - acc: 0.5310 - val_loss: 0.6925 - val_acc: 0.5375
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6911 - acc: 0.5180 - val_loss: 0.6917 - val_acc: 0.5012
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6766 - acc: 0.5500 - val_loss: 0.6669 - val_acc: 0.6075
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6715 - acc: 0.5945 - val_loss: 0.6514 - val_acc: 0.6000
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6305 - acc: 0.6440 - val_loss: 0.6846 - val_acc: 0.6225
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.5993 - acc: 0.6860 - val_loss: 0.6139 - val_acc: 0.6875
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.5471 - acc: 0.7200 - val_loss: 0.6336 - val_acc: 0.7025
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.5164 - acc: 0.7470 - val_loss: 0.6070 - val_acc: 0.7212
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.4326 - acc: 0.8065 - val_loss: 0.6255 - val_acc: 0.7175
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.4121 - acc: 0.8120 - val_loss: 0.6736 - val_acc: 0.7025
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.2949 - acc: 0.8660 - val_loss: 0.8145 - val_acc: 0.6850
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.2373 - acc: 0.9035 - val_loss: 0.8484 - val_acc: 0.7137
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.1654 - acc: 0.9410 - val_loss: 1.0634 - val_acc: 0.71630.931 - ETA: 1s - l
# Epoch 14/25
# 125/125 [==============================] - 5s - loss: 0.1436 - acc: 0.9460 - val_loss: 1.1448 - val_acc: 0.7100
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.1144 - acc: 0.9580 - val_loss: 1.4635 - val_acc: 0.6787
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0654 - acc: 0.9735 - val_loss: 1.3236 - val_acc: 0.7462
# Epoch 17/25
# 125/125 [==============================] - 5s - loss: 0.0560 - acc: 0.9760 - val_loss: 1.3440 - val_acc: 0.7262
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0716 - acc: 0.9725 - val_loss: 1.5029 - val_acc: 0.7225
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0644 - acc: 0.9785 - val_loss: 1.3571 - val_acc: 0.7037
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0464 - acc: 0.9805 - val_loss: 1.3342 - val_acc: 0.7375
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0398 - acc: 0.9835 - val_loss: 1.3986 - val_acc: 0.7025
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0409 - acc: 0.9825 - val_loss: 1.6930 - val_acc: 0.7125
# Epoch 23/25
# 125/125 [==============================] - 7s - loss: 0.0418 - acc: 0.9820 - val_loss: 1.7266 - val_acc: 0.6925
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0475 - acc: 0.9825 - val_loss: 1.4196 - val_acc: 0.7163
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0524 - acc: 0.9750 - val_loss: 1.5956 - val_acc: 0.7000
# 1.38450589538 0.71
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.7030 - acc: 0.5005 - val_loss: 0.6931 - val_acc: 0.4963
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6937 - acc: 0.5080 - val_loss: 0.6928 - val_acc: 0.5262
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6939 - acc: 0.5035 - val_loss: 0.6907 - val_acc: 0.5188
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6928 - acc: 0.5300 - val_loss: 0.6835 - val_acc: 0.5450
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6942 - acc: 0.5275 - val_loss: 0.6867 - val_acc: 0.5487
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6915 - acc: 0.5340 - val_loss: 0.6867 - val_acc: 0.5600
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.6856 - acc: 0.5475 - val_loss: 0.6834 - val_acc: 0.5537
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.6859 - acc: 0.5410 - val_loss: 0.6861 - val_acc: 0.5387
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.6843 - acc: 0.5405 - val_loss: 0.6776 - val_acc: 0.5700
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.6902 - acc: 0.5370 - val_loss: 0.6806 - val_acc: 0.5725
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.6812 - acc: 0.5690 - val_loss: 0.6662 - val_acc: 0.5887
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.6590 - acc: 0.5880 - val_loss: 0.6462 - val_acc: 0.5962
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.6570 - acc: 0.6020 - val_loss: 0.6681 - val_acc: 0.6075
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.6301 - acc: 0.6430 - val_loss: 0.6959 - val_acc: 0.6162
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.6202 - acc: 0.6575 - val_loss: 0.6481 - val_acc: 0.6325
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.5949 - acc: 0.6980 - val_loss: 0.6397 - val_acc: 0.6562
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.5550 - acc: 0.7120 - val_loss: 0.6474 - val_acc: 0.6538
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.5553 - acc: 0.7230 - val_loss: 0.6370 - val_acc: 0.6675
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.5401 - acc: 0.7220 - val_loss: 0.6398 - val_acc: 0.6687
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.5188 - acc: 0.7415 - val_loss: 0.6442 - val_acc: 0.6575
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.4951 - acc: 0.7470 - val_loss: 0.6538 - val_acc: 0.6787
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.4896 - acc: 0.7605 - val_loss: 0.6762 - val_acc: 0.6600
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.4490 - acc: 0.7800 - val_loss: 0.6943 - val_acc: 0.6825
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.4314 - acc: 0.8010 - val_loss: 0.6910 - val_acc: 0.6775TA: 0s - loss: 0.4393 -
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.4203 - acc: 0.8120 - val_loss: 0.6906 - val_acc: 0.6863
# 0.688052155972 0.69375
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6944 - acc: 0.5185 - val_loss: 0.6849 - val_acc: 0.5613
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6907 - acc: 0.5565 - val_loss: 0.6812 - val_acc: 0.5550
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6602 - acc: 0.6110 - val_loss: 0.6903 - val_acc: 0.5863
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6248 - acc: 0.6535 - val_loss: 0.6519 - val_acc: 0.6338
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.5665 - acc: 0.7060 - val_loss: 0.6285 - val_acc: 0.6825
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.4976 - acc: 0.7590 - val_loss: 0.6191 - val_acc: 0.7025
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.4024 - acc: 0.8085 - val_loss: 0.6272 - val_acc: 0.7025
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.3429 - acc: 0.8410 - val_loss: 0.6299 - val_acc: 0.7037
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.2551 - acc: 0.8965 - val_loss: 0.9290 - val_acc: 0.7225
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.1943 - acc: 0.9205 - val_loss: 0.9900 - val_acc: 0.7087
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.1281 - acc: 0.9550 - val_loss: 1.2178 - val_acc: 0.7025
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.0736 - acc: 0.9735 - val_loss: 1.1272 - val_acc: 0.7375
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.0640 - acc: 0.9740 - val_loss: 1.2171 - val_acc: 0.7212
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.0534 - acc: 0.9815 - val_loss: 1.3935 - val_acc: 0.7188
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.0685 - acc: 0.9790 - val_loss: 1.4382 - val_acc: 0.7362
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0516 - acc: 0.9860 - val_loss: 1.5683 - val_acc: 0.6987
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.0430 - acc: 0.9860 - val_loss: 1.4580 - val_acc: 0.7087
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0335 - acc: 0.9885 - val_loss: 1.7179 - val_acc: 0.7037
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0399 - acc: 0.9885 - val_loss: 1.6695 - val_acc: 0.7150
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0302 - acc: 0.9905 - val_loss: 1.5311 - val_acc: 0.6987
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0315 - acc: 0.9910 - val_loss: 1.6656 - val_acc: 0.7300
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0329 - acc: 0.9865 - val_loss: 1.7455 - val_acc: 0.7212ETA: 1s - loss: 0
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0198 - acc: 0.9950 - val_loss: 1.8643 - val_acc: 0.6950
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0393 - acc: 0.9845 - val_loss: 1.6565 - val_acc: 0.7150
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0154 - acc: 0.9935 - val_loss: 1.6232 - val_acc: 0.7312
# 1.70243615687 0.72875
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.6936 - acc: 0.5385 - val_loss: 0.6855 - val_acc: 0.5563
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6648 - acc: 0.6005 - val_loss: 0.6250 - val_acc: 0.6675
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6182 - acc: 0.6525 - val_loss: 0.6125 - val_acc: 0.6837
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.5712 - acc: 0.7125 - val_loss: 0.5753 - val_acc: 0.7025
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.4745 - acc: 0.7655 - val_loss: 0.5954 - val_acc: 0.6925
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.3614 - acc: 0.8405 - val_loss: 0.6653 - val_acc: 0.6775
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.2942 - acc: 0.8725 - val_loss: 0.7605 - val_acc: 0.6725
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.1966 - acc: 0.9220 - val_loss: 0.7840 - val_acc: 0.7163
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.1320 - acc: 0.9515 - val_loss: 0.8989 - val_acc: 0.7350
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.0779 - acc: 0.9735 - val_loss: 1.1033 - val_acc: 0.7238
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.0496 - acc: 0.9810 - val_loss: 1.2052 - val_acc: 0.7288
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.0464 - acc: 0.9855 - val_loss: 1.4613 - val_acc: 0.7075
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.0756 - acc: 0.9730 - val_loss: 1.2903 - val_acc: 0.7200
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.0360 - acc: 0.9855 - val_loss: 1.5163 - val_acc: 0.6987
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.0474 - acc: 0.9890 - val_loss: 1.4076 - val_acc: 0.6913
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.0385 - acc: 0.9885 - val_loss: 1.4306 - val_acc: 0.7250
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.0169 - acc: 0.9950 - val_loss: 1.4972 - val_acc: 0.7238
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0113 - acc: 0.9970 - val_loss: 1.6988 - val_acc: 0.7100
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0271 - acc: 0.9910 - val_loss: 1.4066 - val_acc: 0.7212
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0399 - acc: 0.9860 - val_loss: 1.8408 - val_acc: 0.6887
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0452 - acc: 0.9860 - val_loss: 1.6536 - val_acc: 0.6963
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0586 - acc: 0.9850 - val_loss: 1.5879 - val_acc: 0.7100
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0205 - acc: 0.9940 - val_loss: 1.8177 - val_acc: 0.7100
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0075 - acc: 0.9975 - val_loss: 1.7637 - val_acc: 0.7113
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0100 - acc: 0.9960 - val_loss: 1.8270 - val_acc: 0.7137
# 1.65802486256 0.725
# Evalutation of best performing model:
# [1.546993488445878, 0.7421875]
# {'lr': 0, 'Dropout': 0.23316134447477344}
