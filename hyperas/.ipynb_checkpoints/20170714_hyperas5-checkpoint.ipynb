# %% [markdown]
# # Hyperasの練習
#
# *20170715 Mitsuhiro Ito*
#
#
# * (https://github.com/maxpumperla/hyperas/tree/master/examples)
#
#
# ---

# %%
from __future__ import print_function
import sys
from utils import save_model_viz, save_weights, save_hist, plot_hist
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import uniform, choice, conditional
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
# Out:
# Using TensorFlow backend.

# %%
def data():
    train_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
    
    valid_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')

    valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')
    
    
    
    return train_generator, valid_generator

# %%
def model(train_generator, valid_generator):

    model = Sequential()
    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3), input_shape=(150, 150, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    if conditional({{choice(['three', 'four'])}}) == 'four':
        model.add(Conv2D(64, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense({{choice([32, 64, 128])}}))
    model.add(Activation('relu'))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    batch_size = {{choice([16, 32])}}


    model.fit_generator(train_generator, 
                    steps_per_epoch = 2000 // batch_size, 
                    epochs=25, 
                    verbose=1, 
                    validation_data = valid_generator,
                    validation_steps= 800 // batch_size)
    
    
    score, acc = model.evaluate_generator(generator=valid_generator, 
                                      steps= 800 // batch_size)
    
    print(score, acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
train_generator, valid_generator = data()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=15,
                                      trials=Trials(),
                                      notebook_name='20170714_hyperas5' )
print("Evalutation of best performing model:")
print(best_model.evaluate_generator(valid_generator, steps=64))
print(best_run)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     from utils import save_model_viz, save_weights, save_hist, plot_hist
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import uniform, choice, conditional
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation, Flatten
# except:
#     pass
#
# try:
#     from keras.layers.convolutional import Convolution2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD
# except:
#     pass
#
# try:
#     from keras.preprocessing.image import ImageDataGenerator
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Conv2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.layers import Activation, Dropout, Flatten, Dense
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Conv2D': hp.choice('Conv2D', [32, 64, 128]),
#         'Conv2D_1': hp.choice('Conv2D_1', [32, 64, 128]),
#         'Conv2D_2': hp.choice('Conv2D_2', [32, 64, 128]),
#         'conditional': hp.choice('conditional', ['three', 'four']),
#         'Conv2D_3': hp.choice('Conv2D_3', [32, 64, 128]),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'batch_size': hp.choice('batch_size', [16, 32]),
#     }
#
# >>> Data
#    1:
#    2: train_gan = ImageDataGenerator(rescale=1.0 / 255,
#    3:     featurewise_center=False,  # set input mean to 0 over the dataset
#    4:     samplewise_center=False,  # set each sample mean to 0
#    5:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#    6:     samplewise_std_normalization=False,  # divide each input by its std
#    7:     zca_whitening=False,  # apply ZCA whitening
#    8:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#    9:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   10:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   11:     horizontal_flip=False,  # randomly flip images
#   12:     vertical_flip=False)  # randomly flip images
#   13:
#   14: valid_gan = ImageDataGenerator(rescale=1.0 / 255,
#   15:     featurewise_center=False,  # set input mean to 0 over the dataset
#   16:     samplewise_center=False,  # set each sample mean to 0
#   17:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#   18:     samplewise_std_normalization=False,  # divide each input by its std
#   19:     zca_whitening=False,  # apply ZCA whitening
#   20:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#   21:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   22:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   23:     horizontal_flip=False,  # randomly flip images
#   24:     vertical_flip=False)  # randomly flip images
#   25:
#   26: train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
#   27:     target_size=(150, 150),
#   28:     batch_size=16,
#   29:     class_mode='binary')
#   30:
#   31: valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
#   32:     target_size=(150, 150),
#   33:     batch_size=16,
#   34:     class_mode='binary')
#   35:
#   36:
#   37:
#   38:
#   39:
#   40:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = Sequential()
#    5:     model.add(Conv2D(space['Conv2D'], (3, 3), input_shape=(150, 150, 3)))
#    6:     model.add(Activation('relu'))
#    7:     model.add(MaxPooling2D(pool_size=(2, 2)))
#    8:
#    9:     model.add(Conv2D(space['Conv2D_1'], (3, 3)))
#   10:     model.add(Activation('relu'))
#   11:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   12:
#   13:     model.add(Conv2D(space['Conv2D_2'], (3, 3)))
#   14:     model.add(Activation('relu'))
#   15:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   16:
#   17:     if conditional(space['conditional']) == 'four':
#   18:         model.add(Conv2D(64, (3, 3)))
#   19:         model.add(Activation('relu'))
#   20:         model.add(MaxPooling2D(pool_size=(2, 2)))
#   21:
#   22:     model.add(Flatten())
#   23:     model.add(Dense(space['Conv2D_3']))
#   24:     model.add(Activation('relu'))
#   25:     model.add(Dropout(space['Dropout']))
#   26:     model.add(Dense(1))
#   27:     model.add(Activation('sigmoid'))
#   28:
#   29:     model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
#   30:
#   31:     batch_size = space['batch_size']
#   32:
#   33:
#   34:     model.fit_generator(train_generator,
#   35:                     steps_per_epoch = 2000 // batch_size,
#   36:                     epochs=25,
#   37:                     verbose=1,
#   38:                     validation_data = valid_generator,
#   39:                     validation_steps= 800 // batch_size)
#   40:
#   41:
#   42:     score, acc = model.evaluate_generator(generator=valid_generator,
#   43:                                       steps= 800 // batch_size)
#   44:
#   45:     print(score, acc)
#   46:
#   47:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   48:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/25
# 62/62 [==============================] - 4s - loss: 0.6998 - acc: 0.5020 - val_loss: 0.6906 - val_acc: 0.5100
# Epoch 2/25
# 62/62 [==============================] - 4s - loss: 0.6944 - acc: 0.5121 - val_loss: 0.6930 - val_acc: 0.5100
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6930 - acc: 0.5050 - val_loss: 0.6929 - val_acc: 0.5150
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.1079 - acc: 0.9637 - val_loss: 1.0294 - val_acc: 0.6900
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.0702 - acc: 0.9718 - val_loss: 1.0214 - val_acc: 0.7225
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.0641 - acc: 0.9758 - val_loss: 1.5271 - val_acc: 0.6875
# Epoch 24/25
# 62/62 [==============================] - 2s - loss: 0.0483 - acc: 0.9839 - val_loss: 0.9971 - val_acc: 0.7475
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.0479 - acc: 0.9839 - val_loss: 1.2786 - val_acc: 0.6925
# 1.2004024303 0.6975
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6946 - acc: 0.5141 - val_loss: 0.6923 - val_acc: 0.5500
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.5040 - val_loss: 0.6929 - val_acc: 0.4950
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5050 - val_loss: 0.6946 - val_acc: 0.4775: 0s - loss: 0.6936 - acc:
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6954 - acc: 0.4940 - val_loss: 0.6924 - val_acc: 0.5200
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.5131 - val_loss: 0.6933 - val_acc: 0.4900
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5111 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4919 - val_loss: 0.6928 - val_acc: 0.5250
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.5171 - val_loss: 0.6927 - val_acc: 0.5250
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6953 - acc: 0.5000 - val_loss: 0.6935 - val_acc: 0.4775
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5030 - val_loss: 0.6931 - val_acc: 0.5050
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4960 - val_loss: 0.6936 - val_acc: 0.4800
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5141 - val_loss: 0.6930 - val_acc: 0.5125
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4919 - val_loss: 0.6932 - val_acc: 0.4900
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4879 - val_loss: 0.6931 - val_acc: 0.52250.4
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4879 - val_loss: 0.6930 - val_acc: 0.5250
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4940 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5071 - val_loss: 0.6937 - val_acc: 0.4725
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4960 - val_loss: 0.6926 - val_acc: 0.5375
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4929 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5141 - val_loss: 0.6933 - val_acc: 0.4925
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.5050 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4647 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.5091 - val_loss: 0.6930 - val_acc: 0.5150
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5050 - val_loss: 0.6932 - val_acc: 0.4725
# 0.693155543804 0.4975
# Evalutation of best performing model:
# [0.68362356722354889, 0.734375]
# {'Conv2D_2': 2, 'Dropout': 0.10530729142803252, 'conditional': 1, 'Conv2D_1': 2, 'batch_size': 1, 'Conv2D': 0, 'Conv2D_3': 0}
