# %% [markdown]
# # Hyperasの練習
#
# *20170715 Mitsuhiro Ito*
#
#
# * (https://github.com/maxpumperla/hyperas/tree/master/examples)
#
#
# ---

# %%
from __future__ import print_function
import sys
from utils import save_model_viz, save_weights, save_hist, plot_hist
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import uniform, choice, conditional
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
# Out:
# Using TensorFlow backend.

# %%
def data():
    train_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
    
    valid_gan = ImageDataGenerator(rescale=1.0 / 255,
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')

    valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
        target_size=(150, 150),
        batch_size=16,
        class_mode='binary')
    
    
    
    return train_generator, valid_generator

# %%
def model(train_generator, valid_generator):

    model = Sequential()
    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3), input_shape=(150, 150, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D({{choice([32, 64, 128])}}, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    if conditional({{choice(['three', 'four'])}}) == 'four':
        model.add(Conv2D(64, (3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense({{choice([32, 64, 128])}}))
    model.add(Activation('relu'))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    batch_size = {{choice([16, 32])}}


    model.fit_generator(train_generator, 
                    steps_per_epoch = 2000 // batch_size, 
                    epochs=25, 
                    verbose=1, 
                    validation_data = valid_generator,
                    validation_steps= 800 // batch_size)
    
    
    score, acc = model.evaluate_generator(generator=valid_generator, 
                                      steps= 800 // batch_size)
    
    print(score, acc)
    
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
train_generator, valid_generator = data()

best_run, best_model = optim.minimize(model=model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=15,
                                      trials=Trials(),
                                      notebook_name='20170714_hyperas4' )
print("Evalutation of best performing model:")
print(best_model.evaluate_generator(valid_generator, steps=64))
print(best_run)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import sys
# except:
#     pass
#
# try:
#     from utils import save_model_viz, save_weights, save_hist, plot_hist
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import uniform, choice, conditional
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation, Flatten
# except:
#     pass
#
# try:
#     from keras.layers.convolutional import Convolution2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.optimizers import SGD
# except:
#     pass
#
# try:
#     from keras.preprocessing.image import ImageDataGenerator
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Conv2D, MaxPooling2D
# except:
#     pass
#
# try:
#     from keras.layers import Activation, Dropout, Flatten, Dense
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Conv2D': hp.choice('Conv2D', [32, 64, 128]),
#         'Conv2D_1': hp.choice('Conv2D_1', [32, 64, 128]),
#         'Conv2D_2': hp.choice('Conv2D_2', [32, 64, 128]),
#         'conditional': hp.choice('conditional', ['three', 'four']),
#         'Conv2D_3': hp.choice('Conv2D_3', [32, 64, 128]),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'batch_size': hp.choice('batch_size', [16, 32]),
#     }
#
# >>> Data
#    1:
#    2: train_gan = ImageDataGenerator(rescale=1.0 / 255,
#    3:     featurewise_center=False,  # set input mean to 0 over the dataset
#    4:     samplewise_center=False,  # set each sample mean to 0
#    5:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#    6:     samplewise_std_normalization=False,  # divide each input by its std
#    7:     zca_whitening=False,  # apply ZCA whitening
#    8:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#    9:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   10:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   11:     horizontal_flip=False,  # randomly flip images
#   12:     vertical_flip=False)  # randomly flip images
#   13:
#   14: valid_gan = ImageDataGenerator(rescale=1.0 / 255,
#   15:     featurewise_center=False,  # set input mean to 0 over the dataset
#   16:     samplewise_center=False,  # set each sample mean to 0
#   17:     featurewise_std_normalization=False,  # divide inputs by std of the dataset
#   18:     samplewise_std_normalization=False,  # divide each input by its std
#   19:     zca_whitening=False,  # apply ZCA whitening
#   20:     rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#   21:     width_shift_range=0,  # randomly shift images horizontally (fraction of total width)
#   22:     height_shift_range=0,  # randomly shift images vertically (fraction of total height)
#   23:     horizontal_flip=False,  # randomly flip images
#   24:     vertical_flip=False)  # randomly flip images
#   25:
#   26: train_generator = train_gan.flow_from_directory('/home/dl/mitsu-work/data/train/',
#   27:     target_size=(150, 150),
#   28:     batch_size=16,
#   29:     class_mode='binary')
#   30:
#   31: valid_generator = valid_gan.flow_from_directory('/home/dl/mitsu-work/data/valid/',
#   32:     target_size=(150, 150),
#   33:     batch_size=16,
#   34:     class_mode='binary')
#   35:
#   36:
#   37:
#   38:
#   39:
#   40:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     model = Sequential()
#    5:     model.add(Conv2D(space['Conv2D'], (3, 3), input_shape=(150, 150, 3)))
#    6:     model.add(Activation('relu'))
#    7:     model.add(MaxPooling2D(pool_size=(2, 2)))
#    8:
#    9:     model.add(Conv2D(space['Conv2D_1'], (3, 3)))
#   10:     model.add(Activation('relu'))
#   11:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   12:
#   13:     model.add(Conv2D(space['Conv2D_2'], (3, 3)))
#   14:     model.add(Activation('relu'))
#   15:     model.add(MaxPooling2D(pool_size=(2, 2)))
#   16:
#   17:     if conditional(space['conditional']) == 'four':
#   18:         model.add(Conv2D(64, (3, 3)))
#   19:         model.add(Activation('relu'))
#   20:         model.add(MaxPooling2D(pool_size=(2, 2)))
#   21:
#   22:     model.add(Flatten())
#   23:     model.add(Dense(space['Conv2D_3']))
#   24:     model.add(Activation('relu'))
#   25:     model.add(Dropout(space['Dropout']))
#   26:     model.add(Dense(1))
#   27:     model.add(Activation('sigmoid'))
#   28:
#   29:     model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
#   30:
#   31:     batch_size = space['batch_size']
#   32:
#   33:
#   34:     model.fit_generator(train_generator,
#   35:                     steps_per_epoch = 2000 // batch_size,
#   36:                     epochs=25,
#   37:                     verbose=1,
#   38:                     validation_data = valid_generator,
#   39:                     validation_steps= 800 // batch_size)
#   40:
#   41:
#   42:     score, acc = model.evaluate_generator(generator=valid_generator,
#   43:                                       steps= 800 // batch_size)
#   44:
#   45:     print(score, acc)
#   46:
#   47:     return {'loss': -acc, 'status': STATUS_OK, 'model': model}
#   48:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.
# Epoch 1/25
# 62/62 [==============================] - 4s - loss: 0.7018 - acc: 0.5071 - val_loss: 0.6930 - val_acc: 0.4950
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6954 - acc: 0.5242 - val_loss: 0.6933 - val_acc: 0.4950
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.4980 - val_loss: 0.6930 - val_acc: 0.5075
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4879 - val_loss: 0.6874 - val_acc: 0.5175
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6974 - acc: 0.5454 - val_loss: 0.6931 - val_acc: 0.5125
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6942 - acc: 0.4960 - val_loss: 0.6929 - val_acc: 0.5125
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6930 - acc: 0.5131 - val_loss: 0.6944 - val_acc: 0.4750
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6990 - acc: 0.5091 - val_loss: 0.6884 - val_acc: 0.5550
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6939 - acc: 0.4798 - val_loss: 0.6929 - val_acc: 0.5125
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6819 - acc: 0.5171 - val_loss: 0.6876 - val_acc: 0.61000.
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6706 - acc: 0.5847 - val_loss: 0.6659 - val_acc: 0.6250
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6929 - acc: 0.5585 - val_loss: 0.6835 - val_acc: 0.5700
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6660 - acc: 0.5988 - val_loss: 0.6703 - val_acc: 0.6425
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6604 - acc: 0.6179 - val_loss: 0.6704 - val_acc: 0.6025
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6329 - acc: 0.6341 - val_loss: 0.6756 - val_acc: 0.6300
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6440 - acc: 0.6381 - val_loss: 0.6202 - val_acc: 0.6725
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6157 - acc: 0.6895 - val_loss: 0.6434 - val_acc: 0.6375
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6162 - acc: 0.6694 - val_loss: 0.6456 - val_acc: 0.6300
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.5999 - acc: 0.6956 - val_loss: 0.5998 - val_acc: 0.6900
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.5978 - acc: 0.6774 - val_loss: 0.6713 - val_acc: 0.6050
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.5531 - acc: 0.7218 - val_loss: 0.6112 - val_acc: 0.6900
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.5416 - acc: 0.7298 - val_loss: 0.6118 - val_acc: 0.6900
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.4924 - acc: 0.7581 - val_loss: 0.6472 - val_acc: 0.6725
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.4877 - acc: 0.7591 - val_loss: 0.6074 - val_acc: 0.6650
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.4720 - acc: 0.7661 - val_loss: 0.6532 - val_acc: 0.6925
# 0.618372023106 0.695
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6972 - acc: 0.5105 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6937 - acc: 0.4870 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6931 - acc: 0.5055 - val_loss: 0.6931 - val_acc: 0.5100
# Epoch 4/25
# 125/125 [==============================] - 7s - loss: 0.6934 - acc: 0.4755 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6934 - acc: 0.5005 - val_loss: 0.6933 - val_acc: 0.4888
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6934 - acc: 0.4975 - val_loss: 0.6929 - val_acc: 0.5150
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.6939 - acc: 0.4880 - val_loss: 0.6932 - val_acc: 0.4963
# Epoch 8/25
# 125/125 [==============================] - 7s - loss: 0.6951 - acc: 0.4885 - val_loss: 0.6933 - val_acc: 0.4950
# Epoch 9/25
# 125/125 [==============================] - 7s - loss: 0.6931 - acc: 0.4945 - val_loss: 0.6931 - val_acc: 0.4963
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.6939 - acc: 0.5075 - val_loss: 0.6931 - val_acc: 0.5088
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.6950 - acc: 0.4790 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 12/25
# 125/125 [==============================] - 7s - loss: 0.6942 - acc: 0.4875 - val_loss: 0.6931 - val_acc: 0.5088
# Epoch 13/25
# 125/125 [==============================] - 7s - loss: 0.6931 - acc: 0.5115 - val_loss: 0.6932 - val_acc: 0.4925
# Epoch 14/25
# 125/125 [==============================] - 7s - loss: 0.6938 - acc: 0.4995 - val_loss: 0.6933 - val_acc: 0.4888
# Epoch 15/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.5040 - val_loss: 0.6933 - val_acc: 0.4938
# Epoch 16/25
# 125/125 [==============================] - 7s - loss: 0.6936 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 17/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.4895 - val_loss: 0.6932 - val_acc: 0.4863
# Epoch 18/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.4970 - val_loss: 0.6932 - val_acc: 0.4988
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.6924 - acc: 0.5035 - val_loss: 0.6931 - val_acc: 0.5062
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.6938 - acc: 0.4870 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 21/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.5055 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 22/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.5005 - val_loss: 0.6932 - val_acc: 0.4988
# Epoch 23/25
# 125/125 [==============================] - 7s - loss: 0.6935 - acc: 0.5020 - val_loss: 0.6931 - val_acc: 0.5012
# Epoch 24/25
# 125/125 [==============================] - 7s - loss: 0.6930 - acc: 0.5130 - val_loss: 0.6932 - val_acc: 0.4988
# Epoch 25/25
# 125/125 [==============================] - 7s - loss: 0.6936 - acc: 0.4780 - val_loss: 0.6931 - val_acc: 0.5000
# 0.693140802383 0.5025
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6942 - acc: 0.5225 - val_loss: 0.6924 - val_acc: 0.4988
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6915 - acc: 0.5145 - val_loss: 0.6583 - val_acc: 0.6350
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6853 - acc: 0.5575 - val_loss: 0.6722 - val_acc: 0.5750
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6718 - acc: 0.5945 - val_loss: 0.6442 - val_acc: 0.6200oss: 0.6725 - acc: 0
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6288 - acc: 0.6480 - val_loss: 0.6053 - val_acc: 0.6800
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6014 - acc: 0.6765 - val_loss: 0.5971 - val_acc: 0.6813
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.5573 - acc: 0.7300 - val_loss: 0.6506 - val_acc: 0.6500
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.5430 - acc: 0.7205 - val_loss: 0.6210 - val_acc: 0.6850
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.4670 - acc: 0.7830 - val_loss: 0.5990 - val_acc: 0.7212
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.4165 - acc: 0.7995 - val_loss: 0.6220 - val_acc: 0.7200
# Epoch 11/25
# 125/125 [==============================] - 7s - loss: 0.3277 - acc: 0.8555 - val_loss: 0.6029 - val_acc: 0.7575
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.2589 - acc: 0.8895 - val_loss: 0.8743 - val_acc: 0.7025
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.1930 - acc: 0.9220 - val_loss: 0.8796 - val_acc: 0.7188
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.1546 - acc: 0.9420 - val_loss: 0.8489 - val_acc: 0.7488
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.1123 - acc: 0.9580 - val_loss: 1.2122 - val_acc: 0.7000
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.1018 - acc: 0.9615 - val_loss: 1.0830 - val_acc: 0.7650
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.0865 - acc: 0.9700 - val_loss: 1.1797 - val_acc: 0.7375
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.0363 - acc: 0.9875 - val_loss: 1.5507 - val_acc: 0.7325
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0840 - acc: 0.9760 - val_loss: 1.3004 - val_acc: 0.7338
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0450 - acc: 0.9860 - val_loss: 1.2723 - val_acc: 0.7262
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0235 - acc: 0.9945 - val_loss: 1.7144 - val_acc: 0.7312
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0503 - acc: 0.9870 - val_loss: 1.7221 - val_acc: 0.7013
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0263 - acc: 0.9910 - val_loss: 1.3320 - val_acc: 0.7450
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0170 - acc: 0.9955 - val_loss: 1.6721 - val_acc: 0.7575
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0407 - acc: 0.9865 - val_loss: 1.6500 - val_acc: 0.7137
# 1.24745010301 0.765
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6962 - acc: 0.5060 - val_loss: 0.6932 - val_acc: 0.5025
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.5101 - val_loss: 0.6934 - val_acc: 0.4900
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4829 - val_loss: 0.6931 - val_acc: 0.4975
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4889 - val_loss: 0.6932 - val_acc: 0.4900
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5141 - val_loss: 0.6930 - val_acc: 0.5125
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4889 - val_loss: 0.6931 - val_acc: 0.5275
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4808 - val_loss: 0.6932 - val_acc: 0.4675
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5101 - val_loss: 0.6930 - val_acc: 0.5200
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4556 - val_loss: 0.6932 - val_acc: 0.4725
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4698 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4929 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5040 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4516 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4950 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4849 - val_loss: 0.6932 - val_acc: 0.4725
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4879 - val_loss: 0.6932 - val_acc: 0.4775
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4960 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4829 - val_loss: 0.6932 - val_acc: 0.4975
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4819 - val_loss: 0.6932 - val_acc: 0.4850
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4728 - val_loss: 0.6932 - val_acc: 0.4900
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4899 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6931 - val_acc: 0.5025
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4738 - val_loss: 0.6932 - val_acc: 0.4900
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4849 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4869 - val_loss: 0.6932 - val_acc: 0.4875
# 0.693118379116 0.515
# Epoch 1/25
# 125/125 [==============================] - 7s - loss: 0.6969 - acc: 0.4835 - val_loss: 0.6932 - val_acc: 0.4888
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6935 - acc: 0.5040 - val_loss: 0.6932 - val_acc: 0.4888
# Epoch 3/25
# 125/125 [==============================] - 7s - loss: 0.6936 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.5038
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6936 - acc: 0.4985 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 5/25
# 125/125 [==============================] - 7s - loss: 0.6943 - acc: 0.4840 - val_loss: 0.6931 - val_acc: 0.5100
# Epoch 6/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4880 - val_loss: 0.6932 - val_acc: 0.4963
# Epoch 7/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.4965 - val_loss: 0.6929 - val_acc: 0.5175
# Epoch 8/25
# 125/125 [==============================] - 7s - loss: 0.6936 - acc: 0.4860 - val_loss: 0.6932 - val_acc: 0.4900
# Epoch 9/25
# 125/125 [==============================] - 7s - loss: 0.6937 - acc: 0.4935 - val_loss: 0.6929 - val_acc: 0.5212
# Epoch 10/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.5010 - val_loss: 0.6889 - val_acc: 0.5663
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.5240 - val_loss: 0.6887 - val_acc: 0.5637
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.6944 - acc: 0.5130 - val_loss: 0.6918 - val_acc: 0.5138
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.6942 - acc: 0.5155 - val_loss: 0.6891 - val_acc: 0.5050
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.6951 - acc: 0.4945 - val_loss: 0.6909 - val_acc: 0.5288
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.6922 - acc: 0.5140 - val_loss: 0.6903 - val_acc: 0.5475
# Epoch 16/25
# 125/125 [==============================] - 7s - loss: 0.6896 - acc: 0.5410 - val_loss: 0.6926 - val_acc: 0.5025
# Epoch 17/25
# 125/125 [==============================] - 7s - loss: 0.6892 - acc: 0.5485 - val_loss: 0.6821 - val_acc: 0.5813
# Epoch 18/25
# 125/125 [==============================] - 7s - loss: 0.6860 - acc: 0.5475 - val_loss: 0.6797 - val_acc: 0.5575
# Epoch 19/25
# 125/125 [==============================] - 7s - loss: 0.6578 - acc: 0.6075 - val_loss: 0.6251 - val_acc: 0.6350
# Epoch 20/25
# 125/125 [==============================] - 7s - loss: 0.6452 - acc: 0.6260 - val_loss: 0.6440 - val_acc: 0.6238
# Epoch 21/25
# 125/125 [==============================] - 7s - loss: 0.6066 - acc: 0.6725 - val_loss: 0.5756 - val_acc: 0.7188
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.5828 - acc: 0.6955 - val_loss: 0.5936 - val_acc: 0.6750
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.5378 - acc: 0.7275 - val_loss: 0.5779 - val_acc: 0.7100
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.5185 - acc: 0.7415 - val_loss: 0.5730 - val_acc: 0.7225
# Epoch 25/25
# 125/125 [==============================] - 7s - loss: 0.4531 - acc: 0.7800 - val_loss: 0.6241 - val_acc: 0.7200
# 0.57478990078 0.7225
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.7090 - acc: 0.5252 - val_loss: 0.6931 - val_acc: 0.51500
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6951 - acc: 0.5171 - val_loss: 0.6926 - val_acc: 0.5050
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6938 - acc: 0.4950 - val_loss: 0.6835 - val_acc: 0.5775
# Epoch 4/25
# 62/62 [==============================] - 2s - loss: 0.6872 - acc: 0.5837 - val_loss: 0.6793 - val_acc: 0.5950
# Epoch 5/25
# 62/62 [==============================] - 2s - loss: 0.6840 - acc: 0.5504 - val_loss: 0.6806 - val_acc: 0.5625
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6844 - acc: 0.5635 - val_loss: 0.6799 - val_acc: 0.5675
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6673 - acc: 0.5897 - val_loss: 0.6609 - val_acc: 0.5900
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6649 - acc: 0.5917 - val_loss: 0.6853 - val_acc: 0.5650
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6541 - acc: 0.6210 - val_loss: 0.6110 - val_acc: 0.6600
# Epoch 10/25
# 62/62 [==============================] - 2s - loss: 0.6508 - acc: 0.6300 - val_loss: 0.6801 - val_acc: 0.5750
# Epoch 11/25
# 62/62 [==============================] - 2s - loss: 0.6021 - acc: 0.6714 - val_loss: 0.6956 - val_acc: 0.5850
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.5952 - acc: 0.6683 - val_loss: 0.7400 - val_acc: 0.5925
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.5675 - acc: 0.7046 - val_loss: 0.7249 - val_acc: 0.6200
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.5421 - acc: 0.7278 - val_loss: 0.6465 - val_acc: 0.6300
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.5010 - acc: 0.7550 - val_loss: 0.7507 - val_acc: 0.5925
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.4775 - acc: 0.7732 - val_loss: 0.7640 - val_acc: 0.6075
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.4349 - acc: 0.7802 - val_loss: 0.7620 - val_acc: 0.5875
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.3913 - acc: 0.8155 - val_loss: 0.8382 - val_acc: 0.6250
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.3268 - acc: 0.8558 - val_loss: 0.9109 - val_acc: 0.6275
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.3230 - acc: 0.8468 - val_loss: 0.8338 - val_acc: 0.6325
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.2443 - acc: 0.8931 - val_loss: 1.0006 - val_acc: 0.6325
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.2158 - acc: 0.9133 - val_loss: 1.0837 - val_acc: 0.6525
# Epoch 23/25
# 62/62 [==============================] - 2s - loss: 0.1871 - acc: 0.9224 - val_loss: 1.0461 - val_acc: 0.6700
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.2597 - acc: 0.8962 - val_loss: 1.0573 - val_acc: 0.6000
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.1584 - acc: 0.9476 - val_loss: 1.2626 - val_acc: 0.6375
# 1.43596054912 0.6525
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6966 - acc: 0.4778 - val_loss: 0.6927 - val_acc: 0.4800
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4950 - val_loss: 0.6909 - val_acc: 0.5375
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6868 - acc: 0.5282 - val_loss: 0.6882 - val_acc: 0.5650
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6807 - acc: 0.5655 - val_loss: 0.6796 - val_acc: 0.5800
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6903 - acc: 0.5312 - val_loss: 0.6812 - val_acc: 0.5225
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6709 - acc: 0.5877 - val_loss: 0.6670 - val_acc: 0.6075
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6666 - acc: 0.5877 - val_loss: 0.6123 - val_acc: 0.6875
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6309 - acc: 0.6532 - val_loss: 0.6044 - val_acc: 0.6675
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6037 - acc: 0.6825 - val_loss: 0.6178 - val_acc: 0.6875
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6191 - acc: 0.6613 - val_loss: 0.6315 - val_acc: 0.6800
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.5668 - acc: 0.7147 - val_loss: 0.7400 - val_acc: 0.5650
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.5691 - acc: 0.6905 - val_loss: 0.6245 - val_acc: 0.6500
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.5570 - acc: 0.7016 - val_loss: 0.6292 - val_acc: 0.6925
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.5093 - acc: 0.7631 - val_loss: 0.6516 - val_acc: 0.7025
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.5374 - acc: 0.7278 - val_loss: 0.5657 - val_acc: 0.7200
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.5066 - acc: 0.7520 - val_loss: 0.5614 - val_acc: 0.7450
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.4625 - acc: 0.7742 - val_loss: 0.5509 - val_acc: 0.7500
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.4458 - acc: 0.7802 - val_loss: 0.5767 - val_acc: 0.7200
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.4018 - acc: 0.8206 - val_loss: 0.6211 - val_acc: 0.7350
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.3525 - acc: 0.8377 - val_loss: 0.6137 - val_acc: 0.73500.838
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.3689 - acc: 0.8216 - val_loss: 0.6509 - val_acc: 0.7300
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.3026 - acc: 0.8548 - val_loss: 0.6622 - val_acc: 0.7100
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.2974 - acc: 0.8659 - val_loss: 0.6983 - val_acc: 0.7350
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.2272 - acc: 0.9032 - val_loss: 0.8065 - val_acc: 0.7050
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.2670 - acc: 0.8901 - val_loss: 0.7087 - val_acc: 0.7675
# 0.740877652168 0.73
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.7038 - acc: 0.5101 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6983 - acc: 0.5141 - val_loss: 0.6925 - val_acc: 0.6025
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6915 - acc: 0.5323 - val_loss: 0.7098 - val_acc: 0.5275
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6958 - acc: 0.4990 - val_loss: 0.6922 - val_acc: 0.4875
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6912 - acc: 0.5675 - val_loss: 0.6844 - val_acc: 0.6150
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6864 - acc: 0.5393 - val_loss: 0.6721 - val_acc: 0.5700
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6658 - acc: 0.5948 - val_loss: 0.7075 - val_acc: 0.5225
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6553 - acc: 0.6109 - val_loss: 0.6581 - val_acc: 0.6125
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6105 - acc: 0.6694 - val_loss: 0.6138 - val_acc: 0.6200
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6147 - acc: 0.6542 - val_loss: 0.6246 - val_acc: 0.6550
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.5543 - acc: 0.7137 - val_loss: 0.6272 - val_acc: 0.6475
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.5460 - acc: 0.6925 - val_loss: 0.5698 - val_acc: 0.6975
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.4557 - acc: 0.7883 - val_loss: 0.5891 - val_acc: 0.6775
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.4851 - acc: 0.7369 - val_loss: 0.6587 - val_acc: 0.6775
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.3351 - acc: 0.8387 - val_loss: 0.7137 - val_acc: 0.7025
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.3679 - acc: 0.8478 - val_loss: 0.6861 - val_acc: 0.6975
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.2594 - acc: 0.8810 - val_loss: 0.7184 - val_acc: 0.7050
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.2729 - acc: 0.8952 - val_loss: 0.7946 - val_acc: 0.6850
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.1416 - acc: 0.9546 - val_loss: 1.0093 - val_acc: 0.6775
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.1593 - acc: 0.9335 - val_loss: 0.8542 - val_acc: 0.7200
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.0753 - acc: 0.9758 - val_loss: 0.9703 - val_acc: 0.7150
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.0723 - acc: 0.9768 - val_loss: 1.2097 - val_acc: 0.7075
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.0484 - acc: 0.9859 - val_loss: 1.3254 - val_acc: 0.6750
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.0750 - acc: 0.9728 - val_loss: 1.5322 - val_acc: 0.6675
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.0522 - acc: 0.9869 - val_loss: 1.2114 - val_acc: 0.7125
# 1.27962563872 0.7025
# Epoch 1/25
# 62/62 [==============================] - 4s - loss: 0.7107 - acc: 0.4869 - val_loss: 0.6931 - val_acc: 0.5300
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5121 - val_loss: 0.6931 - val_acc: 0.5250
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6928 - acc: 0.5030 - val_loss: 0.6932 - val_acc: 0.4750
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6930 - acc: 0.4950 - val_loss: 0.6931 - val_acc: 0.5425
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6936 - acc: 0.4990 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.4708 - val_loss: 0.6931 - val_acc: 0.5250
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.4627 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6928 - acc: 0.5202 - val_loss: 0.6934 - val_acc: 0.4900
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6938 - acc: 0.4435 - val_loss: 0.6931 - val_acc: 0.5025
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4940 - val_loss: 0.6933 - val_acc: 0.4825
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6936 - acc: 0.4607 - val_loss: 0.6932 - val_acc: 0.4850
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4909 - val_loss: 0.6932 - val_acc: 0.4875
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4950 - val_loss: 0.6931 - val_acc: 0.5150
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6938 - acc: 0.5030 - val_loss: 0.6931 - val_acc: 0.5025
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6924 - acc: 0.5040 - val_loss: 0.6929 - val_acc: 0.5175
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.5121 - val_loss: 0.6933 - val_acc: 0.4950
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6939 - acc: 0.4899 - val_loss: 0.6931 - val_acc: 0.4975
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5151 - val_loss: 0.6933 - val_acc: 0.4775
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4889 - val_loss: 0.6932 - val_acc: 0.4825
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4909 - val_loss: 0.6932 - val_acc: 0.4825
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.5040 - val_loss: 0.6932 - val_acc: 0.4925
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6932 - val_acc: 0.4775
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5030 - val_loss: 0.6933 - val_acc: 0.4700
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5111 - val_loss: 0.6931 - val_acc: 0.5050
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.4748 - val_loss: 0.6932 - val_acc: 0.4975
# 0.693265023232 0.475
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.6939 - acc: 0.4985 - val_loss: 0.6932 - val_acc: 0.4925
# Epoch 2/25
# 125/125 [==============================] - 6s - loss: 0.6928 - acc: 0.5195 - val_loss: 0.6932 - val_acc: 0.5012
# Epoch 3/25
# 125/125 [==============================] - 6s - loss: 0.6924 - acc: 0.5225 - val_loss: 0.6933 - val_acc: 0.5012
# Epoch 4/25
# 125/125 [==============================] - 6s - loss: 0.6930 - acc: 0.4975 - val_loss: 0.6936 - val_acc: 0.4950
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6907 - acc: 0.5465 - val_loss: 0.6853 - val_acc: 0.5775
# Epoch 6/25
# 125/125 [==============================] - 6s - loss: 0.6729 - acc: 0.6075 - val_loss: 0.6562 - val_acc: 0.5988
# Epoch 7/25
# 125/125 [==============================] - 6s - loss: 0.6500 - acc: 0.6310 - val_loss: 0.6664 - val_acc: 0.6012
# Epoch 8/25
# 125/125 [==============================] - 6s - loss: 0.5935 - acc: 0.6905 - val_loss: 0.6783 - val_acc: 0.6400
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.5769 - acc: 0.7065 - val_loss: 0.6224 - val_acc: 0.6550
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.5250 - acc: 0.7310 - val_loss: 0.6746 - val_acc: 0.6362
# Epoch 11/25
# 125/125 [==============================] - 6s - loss: 0.4896 - acc: 0.7590 - val_loss: 0.6761 - val_acc: 0.6663
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.4282 - acc: 0.8045 - val_loss: 0.8254 - val_acc: 0.6488
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.3585 - acc: 0.8455 - val_loss: 0.8218 - val_acc: 0.6825
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.2922 - acc: 0.8670 - val_loss: 0.8886 - val_acc: 0.6500
# Epoch 15/25
# 125/125 [==============================] - 6s - loss: 0.2207 - acc: 0.9070 - val_loss: 1.0255 - val_acc: 0.6675
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.1749 - acc: 0.9255 - val_loss: 1.2266 - val_acc: 0.6575
# Epoch 17/25
# 125/125 [==============================] - 6s - loss: 0.1769 - acc: 0.9330 - val_loss: 1.0668 - val_acc: 0.6737
# Epoch 18/25
# 125/125 [==============================] - 6s - loss: 0.1171 - acc: 0.9570 - val_loss: 1.2321 - val_acc: 0.6750
# Epoch 19/25
# 125/125 [==============================] - 6s - loss: 0.0919 - acc: 0.9660 - val_loss: 1.4320 - val_acc: 0.6700
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.0757 - acc: 0.9750 - val_loss: 1.5172 - val_acc: 0.6450
# Epoch 21/25
# 125/125 [==============================] - 6s - loss: 0.0669 - acc: 0.9765 - val_loss: 1.7602 - val_acc: 0.6575
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.0697 - acc: 0.9775 - val_loss: 1.5359 - val_acc: 0.6575
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.0571 - acc: 0.9840 - val_loss: 1.7270 - val_acc: 0.6713
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.0323 - acc: 0.9900 - val_loss: 1.9710 - val_acc: 0.6512
# Epoch 25/25
# 125/125 [==============================] - 6s - loss: 0.0377 - acc: 0.9895 - val_loss: 1.9461 - val_acc: 0.6687
# 2.00836347342 0.66625
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6989 - acc: 0.5081 - val_loss: 0.6943 - val_acc: 0.5000
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6944 - acc: 0.4808 - val_loss: 0.6926 - val_acc: 0.4950
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.5060 - val_loss: 0.6934 - val_acc: 0.4875
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4758 - val_loss: 0.6931 - val_acc: 0.5300
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4950 - val_loss: 0.6932 - val_acc: 0.4675
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4688 - val_loss: 0.6931 - val_acc: 0.5225
# Epoch 7/25
# 62/62 [==============================] - 2s - loss: 0.6932 - acc: 0.4990 - val_loss: 0.6928 - val_acc: 0.5250
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4647 - val_loss: 0.6932 - val_acc: 0.4850
# Epoch 9/25
# 62/62 [==============================] - 2s - loss: 0.6932 - acc: 0.4859 - val_loss: 0.6931 - val_acc: 0.5100
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4839 - val_loss: 0.6933 - val_acc: 0.4725
# Epoch 11/25
# 62/62 [==============================] - 2s - loss: 0.6932 - acc: 0.4950 - val_loss: 0.6933 - val_acc: 0.4875
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4869 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4778 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4960 - val_loss: 0.6933 - val_acc: 0.4775
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.4708 - val_loss: 0.6930 - val_acc: 0.5250
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4839 - val_loss: 0.6931 - val_acc: 0.5275
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.5000 - val_loss: 0.6930 - val_acc: 0.5200
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4990 - val_loss: 0.6931 - val_acc: 0.5300
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4980 - val_loss: 0.6931 - val_acc: 0.5225
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4960 - val_loss: 0.6931 - val_acc: 0.5200
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4819 - val_loss: 0.6931 - val_acc: 0.5375
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4909 - val_loss: 0.6930 - val_acc: 0.5250
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4839 - val_loss: 0.6930 - val_acc: 0.5225
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4909 - val_loss: 0.6929 - val_acc: 0.5575
# Epoch 25/25
# 62/62 [==============================] - 2s - loss: 0.6932 - acc: 0.4940 - val_loss: 0.6935 - val_acc: 0.4425
# 0.693056087494 0.515
# Epoch 1/25
# 125/125 [==============================] - 6s - loss: 0.6960 - acc: 0.5065 - val_loss: 0.6931 - val_acc: 0.4975
# Epoch 2/25
# 125/125 [==============================] - 7s - loss: 0.6943 - acc: 0.5095 - val_loss: 0.6932 - val_acc: 0.4963
# Epoch 3/25
# 125/125 [==============================] - 7s - loss: 0.6934 - acc: 0.4925 - val_loss: 0.6930 - val_acc: 0.5175
# Epoch 4/25
# 125/125 [==============================] - 7s - loss: 0.6935 - acc: 0.4815 - val_loss: 0.6934 - val_acc: 0.4750
# Epoch 5/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4865 - val_loss: 0.6933 - val_acc: 0.4950
# Epoch 6/25
# 125/125 [==============================] - 7s - loss: 0.6936 - acc: 0.4720 - val_loss: 0.6931 - val_acc: 0.5025
# Epoch 7/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.4975 - val_loss: 0.6932 - val_acc: 0.4963
# Epoch 8/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.5050 - val_loss: 0.6932 - val_acc: 0.4988
# Epoch 9/25
# 125/125 [==============================] - 6s - loss: 0.6931 - acc: 0.5030 - val_loss: 0.6932 - val_acc: 0.4963
# Epoch 10/25
# 125/125 [==============================] - 6s - loss: 0.6934 - acc: 0.4715 - val_loss: 0.6932 - val_acc: 0.4938
# Epoch 11/25
# 125/125 [==============================] - 7s - loss: 0.6933 - acc: 0.5000 - val_loss: 0.6931 - val_acc: 0.4975
# Epoch 12/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.5060 - val_loss: 0.6931 - val_acc: 0.5050
# Epoch 13/25
# 125/125 [==============================] - 6s - loss: 0.6933 - acc: 0.4845 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 14/25
# 125/125 [==============================] - 6s - loss: 0.6933 - acc: 0.4735 - val_loss: 0.6931 - val_acc: 0.5075
# Epoch 15/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4980 - val_loss: 0.6931 - val_acc: 0.50000
# Epoch 16/25
# 125/125 [==============================] - 6s - loss: 0.6931 - acc: 0.5090 - val_loss: 0.6932 - val_acc: 0.4988
# Epoch 17/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4820 - val_loss: 0.6932 - val_acc: 0.4950
# Epoch 18/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6931 - val_acc: 0.5012
# Epoch 19/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4845 - val_loss: 0.6931 - val_acc: 0.5038
# Epoch 20/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4875 - val_loss: 0.6932 - val_acc: 0.4913
# Epoch 21/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4855 - val_loss: 0.6931 - val_acc: 0.5062
# Epoch 22/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4890 - val_loss: 0.6931 - val_acc: 0.5050
# Epoch 23/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4860 - val_loss: 0.6931 - val_acc: 0.4950
# Epoch 24/25
# 125/125 [==============================] - 6s - loss: 0.6932 - acc: 0.4820 - val_loss: 0.6931 - val_acc: 0.5200
# Epoch 25/25
# 125/125 [==============================] - 7s - loss: 0.6932 - acc: 0.4785 - val_loss: 0.6931 - val_acc: 0.5212
# 0.693188630342 0.49125
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6985 - acc: 0.4919 - val_loss: 0.6931 - val_acc: 0.4975
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6926 - acc: 0.5192 - val_loss: 0.6930 - val_acc: 0.4825
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6927 - acc: 0.5131 - val_loss: 0.6830 - val_acc: 0.6150
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6929 - acc: 0.5232 - val_loss: 0.6942 - val_acc: 0.4875
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.5040 - val_loss: 0.6928 - val_acc: 0.5150
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6934 - acc: 0.4869 - val_loss: 0.6937 - val_acc: 0.4775
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6941 - acc: 0.4778 - val_loss: 0.6921 - val_acc: 0.5250
# Epoch 8/25
# 62/62 [==============================] - 2s - loss: 0.6937 - acc: 0.5262 - val_loss: 0.6928 - val_acc: 0.5125
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.5060 - val_loss: 0.6920 - val_acc: 0.53000.507
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6936 - acc: 0.5403 - val_loss: 0.6869 - val_acc: 0.5175
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5222 - val_loss: 0.6890 - val_acc: 0.5425
# Epoch 12/25
# 62/62 [==============================] - 2s - loss: 0.6672 - acc: 0.6028 - val_loss: 0.6605 - val_acc: 0.5700
# Epoch 13/25
# 62/62 [==============================] - 2s - loss: 0.6677 - acc: 0.6069 - val_loss: 0.6900 - val_acc: 0.5425
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6692 - acc: 0.5786 - val_loss: 0.6667 - val_acc: 0.6000
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6387 - acc: 0.6512 - val_loss: 0.6294 - val_acc: 0.6550
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6314 - acc: 0.6704 - val_loss: 0.6436 - val_acc: 0.6100
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6331 - acc: 0.6492 - val_loss: 0.6073 - val_acc: 0.6800
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6096 - acc: 0.6764 - val_loss: 0.6465 - val_acc: 0.6375
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.5949 - acc: 0.6734 - val_loss: 0.5862 - val_acc: 0.6875
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.5842 - acc: 0.7036 - val_loss: 0.5839 - val_acc: 0.6975
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.5963 - acc: 0.7006 - val_loss: 0.5897 - val_acc: 0.6825
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.5605 - acc: 0.7268 - val_loss: 0.5682 - val_acc: 0.7025
# Epoch 23/25
# 62/62 [==============================] - 2s - loss: 0.5499 - acc: 0.7167 - val_loss: 0.5801 - val_acc: 0.7175
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.5351 - acc: 0.7440 - val_loss: 0.6113 - val_acc: 0.6700
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.5306 - acc: 0.7409 - val_loss: 0.5774 - val_acc: 0.7025
# 0.620985356569 0.6975
# Epoch 1/25
# 62/62 [==============================] - 4s - loss: 0.7066 - acc: 0.5020 - val_loss: 0.6893 - val_acc: 0.5375
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6918 - acc: 0.5474 - val_loss: 0.6749 - val_acc: 0.6300
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6837 - acc: 0.5585 - val_loss: 0.7040 - val_acc: 0.5025
# Epoch 4/25
# 62/62 [==============================] - 2s - loss: 0.6690 - acc: 0.5776 - val_loss: 0.6554 - val_acc: 0.5800
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6484 - acc: 0.6310 - val_loss: 0.6416 - val_acc: 0.6900
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6311 - acc: 0.6492 - val_loss: 0.6265 - val_acc: 0.6450
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6002 - acc: 0.6724 - val_loss: 0.6270 - val_acc: 0.6450
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.5875 - acc: 0.6855 - val_loss: 0.6198 - val_acc: 0.6500
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.5746 - acc: 0.7046 - val_loss: 0.6136 - val_acc: 0.6375
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.5512 - acc: 0.7278 - val_loss: 0.5504 - val_acc: 0.7425
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.5220 - acc: 0.7560 - val_loss: 0.5656 - val_acc: 0.6950
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.4786 - acc: 0.7792 - val_loss: 0.6367 - val_acc: 0.6775
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.4568 - acc: 0.7944 - val_loss: 0.5615 - val_acc: 0.7000
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.4301 - acc: 0.7994 - val_loss: 0.6537 - val_acc: 0.6800
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.3878 - acc: 0.8256 - val_loss: 0.6041 - val_acc: 0.6950
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.3612 - acc: 0.8387 - val_loss: 0.8698 - val_acc: 0.6950
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.2969 - acc: 0.8740 - val_loss: 0.5969 - val_acc: 0.7225
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.2800 - acc: 0.8730 - val_loss: 0.8514 - val_acc: 0.6825
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.2522 - acc: 0.8881 - val_loss: 0.7346 - val_acc: 0.6875
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.2169 - acc: 0.9083 - val_loss: 0.7422 - val_acc: 0.6900
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.1877 - acc: 0.9244 - val_loss: 0.8020 - val_acc: 0.7175
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.1737 - acc: 0.9304 - val_loss: 0.9266 - val_acc: 0.6850
# Epoch 23/25
# 62/62 [==============================] - 2s - loss: 0.1311 - acc: 0.9496 - val_loss: 0.9932 - val_acc: 0.6850
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.1281 - acc: 0.9577 - val_loss: 1.1698 - val_acc: 0.7000
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.0909 - acc: 0.9677 - val_loss: 1.2883 - val_acc: 0.6775
# 1.23099097431 0.685
# Epoch 1/25
# 62/62 [==============================] - 3s - loss: 0.6983 - acc: 0.5101 - val_loss: 0.6938 - val_acc: 0.4775
# Epoch 2/25
# 62/62 [==============================] - 3s - loss: 0.6933 - acc: 0.5050 - val_loss: 0.6915 - val_acc: 0.5150
# Epoch 3/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5514 - val_loss: 0.6683 - val_acc: 0.5375
# Epoch 4/25
# 62/62 [==============================] - 3s - loss: 0.6949 - acc: 0.4859 - val_loss: 0.6931 - val_acc: 0.5300
# Epoch 5/25
# 62/62 [==============================] - 3s - loss: 0.6935 - acc: 0.4829 - val_loss: 0.6930 - val_acc: 0.4975
# Epoch 6/25
# 62/62 [==============================] - 3s - loss: 0.6931 - acc: 0.5141 - val_loss: 0.6928 - val_acc: 0.4950
# Epoch 7/25
# 62/62 [==============================] - 3s - loss: 0.6937 - acc: 0.5181 - val_loss: 0.6917 - val_acc: 0.5125
# Epoch 8/25
# 62/62 [==============================] - 3s - loss: 0.6947 - acc: 0.5040 - val_loss: 0.6923 - val_acc: 0.5200
# Epoch 9/25
# 62/62 [==============================] - 3s - loss: 0.6930 - acc: 0.5091 - val_loss: 0.6927 - val_acc: 0.5175
# Epoch 10/25
# 62/62 [==============================] - 3s - loss: 0.6932 - acc: 0.4839 - val_loss: 0.6908 - val_acc: 0.5125
# Epoch 11/25
# 62/62 [==============================] - 3s - loss: 0.6936 - acc: 0.5121 - val_loss: 0.6929 - val_acc: 0.5025
# Epoch 12/25
# 62/62 [==============================] - 3s - loss: 0.6926 - acc: 0.5181 - val_loss: 0.6914 - val_acc: 0.5000
# Epoch 13/25
# 62/62 [==============================] - 3s - loss: 0.6909 - acc: 0.5433 - val_loss: 0.6929 - val_acc: 0.4975
# Epoch 14/25
# 62/62 [==============================] - 3s - loss: 0.6887 - acc: 0.5373 - val_loss: 0.6702 - val_acc: 0.5875
# Epoch 15/25
# 62/62 [==============================] - 3s - loss: 0.6806 - acc: 0.5454 - val_loss: 0.6769 - val_acc: 0.5050
# Epoch 16/25
# 62/62 [==============================] - 3s - loss: 0.6771 - acc: 0.5665 - val_loss: 0.6741 - val_acc: 0.5550
# Epoch 17/25
# 62/62 [==============================] - 3s - loss: 0.6494 - acc: 0.5948 - val_loss: 0.6766 - val_acc: 0.5775
# Epoch 18/25
# 62/62 [==============================] - 3s - loss: 0.6891 - acc: 0.5444 - val_loss: 0.6859 - val_acc: 0.5375
# Epoch 19/25
# 62/62 [==============================] - 3s - loss: 0.6527 - acc: 0.6018 - val_loss: 0.6527 - val_acc: 0.6175
# Epoch 20/25
# 62/62 [==============================] - 3s - loss: 0.6498 - acc: 0.6149 - val_loss: 0.6849 - val_acc: 0.6050
# Epoch 21/25
# 62/62 [==============================] - 3s - loss: 0.6207 - acc: 0.6452 - val_loss: 0.5773 - val_acc: 0.7150
# Epoch 22/25
# 62/62 [==============================] - 3s - loss: 0.5969 - acc: 0.6815 - val_loss: 0.6302 - val_acc: 0.6200
# Epoch 23/25
# 62/62 [==============================] - 3s - loss: 0.5782 - acc: 0.7016 - val_loss: 0.5876 - val_acc: 0.6700
# Epoch 24/25
# 62/62 [==============================] - 3s - loss: 0.5569 - acc: 0.6956 - val_loss: 0.6082 - val_acc: 0.6900
# Epoch 25/25
# 62/62 [==============================] - 3s - loss: 0.5394 - acc: 0.7319 - val_loss: 0.5635 - val_acc: 0.6950
# 0.572231506109 0.7025
# Evalutation of best performing model:
# [1.3238170041004196, 0.7568359375]
# {'Conv2D_1': 0, 'Conv2D_2': 2, 'batch_size': 0, 'conditional': 1, 'Dropout': 0.288662535902546, 'Conv2D': 1, 'Conv2D_3': 1}
